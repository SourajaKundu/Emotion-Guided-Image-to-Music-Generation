# %% [markdown]
# # **Melody Generation from Images**

# %% [markdown]
# ## **Importing Libraries**

# %%
print("no problem")
# Out:
# no problem

# %%
from numpy import array
from pickle import load, dump
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import add
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from glob import glob
import os
from numpy import argmax
from music21 import converter, instrument, note, chord, stream, meter,duration, interval, pitch, tempo, midi
from tensorflow.keras.applications.inception_v3 import InceptionV3

from os import listdir
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
# Out:
# 2024-07-05 10:13:55.033618: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-05 10:13:55.087082: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# **Mount Drive**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# To include data folder into drive,
# go to the below link and click on add shortcut to drive
# https://drive.google.com/drive/folders/1TTg5wH78eE0yR_OHJZTJzF3wGv8t0Q1x?usp=sharing

# %% [markdown]
# **Declare Constants**

# %%
pwd
# Out:
# '/mnt/f52b0f59-0748-461c-8e5b-0370230b7e20a1f0bb/Paper1'

# %%
#data folder path
# data_dir = r'E:\uniSlides\CS\Research\FinalDataset\FinalData\unique_2VGG_FINAL\\'
data_dir = ""
#midi note and duration separator
separator = "@"
#image classifier model labels
label_VGG16 = "VGG16"
label_InceptionV3 = "InceptionV3"
#image model currently in use
current_ImgModel = label_VGG16

# %% [markdown]
# ## **Midi Preprocessing**

# %% [markdown]
# Obtain all midi files from folder

# %%
# songs = glob(data_dir + 'midi/*.MID')
songs = glob('audio/*.mid')
songs.sort()
songs
# Out:
# ['audio/0001.mid',
#  'audio/0002.mid',
#  'audio/0003.mid',
#  'audio/0004.mid',
#  'audio/0005.mid',
#  'audio/0006.mid',
#  'audio/0007.mid',
#  'audio/0008.mid',
#  'audio/0009.mid',
#  'audio/0010.mid',
#  'audio/0011.mid',
#  'audio/0012.mid',
#  'audio/0013.mid',
#  'audio/0014.mid',
#  'audio/0015.mid',
#  'audio/0016.mid',
#  'audio/0017.mid',
#  'audio/0018.mid',
#  'audio/0019.mid',
#  'audio/0020.mid',
#  'audio/0021.mid',
#  'audio/0022.mid',
#  'audio/0023.mid',
#  'audio/0024.mid',
#  'audio/0025.mid',
#  'audio/0026.mid',
#  'audio/0027.mid',
#  'audio/0028.mid',
#  'audio/0029.mid',
#  'audio/0030.mid',
#  'audio/0031.mid',
#  'audio/0032.mid',
#  'audio/0033.mid',
#  'audio/0034.mid',
#  'audio/0035.mid',
#  'audio/0036.mid',
#  'audio/0037.mid',
#  'audio/0038.mid',
#  'audio/0039.mid',
#  'audio/0040.mid',
#  'audio/0041.mid',
#  'audio/0042.mid',
#  'audio/0043.mid',
#  'audio/0044.mid',
#  'audio/0045.mid',
#  'audio/0046.mid',
#  'audio/0047.mid',
#  'audio/0048.mid',
#  'audio/0049.mid',
#  'audio/0050.mid',
#  'audio/0051.mid',
#  'audio/0052.mid',
#  'audio/0053.mid',
#  'audio/0054.mid',
#  'audio/0055.mid',
#  'audio/0056.mid',
#  'audio/0057.mid',
#  'audio/0058.mid',
#  'audio/0059.mid',
#  'audio/0060.mid',
#  'audio/0061.mid',
#  'audio/0062.mid',
#  'audio/0063.mid',
#  'audio/0064.mid',
#  'audio/0065.mid',
#  'audio/0066.mid',
#  'audio/0067.mid',
#  'audio/0068.mid',
#  'audio/0069.mid',
#  'audio/0070.mid',
#  'audio/0071.mid',
#  'audio/0072.mid',
#  'audio/0073.mid',
#  'audio/0074.mid',
#  'audio/0075.mid',
#  'audio/0076.mid',
#  'audio/0077.mid',
#  'audio/0078.mid',
#  'audio/0079.mid',
#  'audio/0080.mid',
#  'audio/0081.mid',
#  'audio/0082.mid',
#  'audio/0083.mid',
#  'audio/0084.mid',
#  'audio/0085.mid',
#  'audio/0086.mid',
#  'audio/0087.mid',
#  'audio/0088.mid',
#  'audio/0089.mid',
#  'audio/0090.mid',
#  'audio/0091.mid',
#  'audio/0092.mid',
#  'audio/0093.mid',
#  'audio/0094.mid',
#  'audio/0095.mid',
#  'audio/0096.mid',
#  'audio/0097.mid',
#  'audio/0098.mid',
#  'audio/0099.mid',
#  'audio/0100.mid',
#  'audio/0101.mid',
#  'audio/0102.mid',
#  'audio/0103.mid',
#  'audio/0104.mid',
#  'audio/0105.mid',
#  'audio/0106.mid',
#  'audio/0107.mid',
#  'audio/0108.mid',
#  'audio/0109.mid',
#  'audio/0110.mid',
#  'audio/0111.mid',
#  'audio/0112.mid',
#  'audio/0113.mid',
#  'audio/0114.mid',
#  'audio/0115.mid',
#  'audio/0116.mid',
#  'audio/0117.mid',
#  'audio/0118.mid',
#  'audio/0119.mid',
#  'audio/0120.mid',
#  'audio/0121.mid',
#  'audio/0122.mid',
#  'audio/0123.mid',
#  'audio/0124.mid',
#  'audio/0125.mid',
#  'audio/0126.mid',
#  'audio/0127.mid',
#  'audio/0128.mid',
#  'audio/0129.mid',
#  'audio/0130.mid',
#  'audio/0131.mid',
#  'audio/0132.mid',
#  'audio/0133.mid',
#  'audio/0134.mid',
#  'audio/0135.mid',
#  'audio/0136.mid',
#  'audio/0137.mid',
#  'audio/0138.mid',
#  'audio/0139.mid',
#  'audio/0140.mid',
#  'audio/0141.mid',
#  'audio/0142.mid',
#  'audio/0143.mid',
#  'audio/0144.mid',
#  'audio/0145.mid',
#  'audio/0146.mid',
#  'audio/0147.mid',
#  'audio/0148.mid',
#  'audio/0149.mid',
#  'audio/0150.mid',
#  'audio/0151.mid',
#  'audio/0152.mid',
#  'audio/0153.mid',
#  'audio/0154.mid',
#  'audio/0155.mid',
#  'audio/0156.mid',
#  'audio/0157.mid',
#  'audio/0158.mid',
#  'audio/0159.mid',
#  'audio/0160.mid',
#  'audio/0161.mid',
#  'audio/0162.mid',
#  'audio/0163.mid',
#  'audio/0164.mid',
#  'audio/0165.mid',
#  'audio/0166.mid',
#  'audio/0167.mid',
#  'audio/0168.mid',
#  'audio/0169.mid',
#  'audio/0170.mid',
#  'audio/0171.mid',
#  'audio/0172.mid',
#  'audio/0173.mid',
#  'audio/0174.mid',
#  'audio/0175.mid',
#  'audio/0176.mid',
#  'audio/0177.mid',
#  'audio/0178.mid',
#  'audio/0179.mid',
#  'audio/0180.mid',
#  'audio/0181.mid',
#  'audio/0182.mid',
#  'audio/0183.mid',
#  'audio/0184.mid',
#  'audio/0185.mid',
#  'audio/0186.mid',
#  'audio/0187.mid',
#  'audio/0188.mid',
#  'audio/0189.mid',
#  'audio/0190.mid',
#  'audio/0191.mid',
#  'audio/0192.mid',
#  'audio/0193.mid',
#  'audio/0194.mid',
#  'audio/0195.mid',
#  'audio/0196.mid',
#  'audio/0197.mid',
#  'audio/0198.mid',
#  'audio/0199.mid',
#  'audio/0200.mid',
#  'audio/0201.mid',
#  'audio/0202.mid',
#  'audio/0203.mid',
#  'audio/0204.mid',
#  'audio/0205.mid',
#  'audio/0206.mid',
#  'audio/0207.mid',
#  'audio/0208.mid',
#  'audio/0209.mid',
#  'audio/0210.mid',
#  'audio/0211.mid',
#  'audio/0212.mid',
#  'audio/0213.mid',
#  'audio/0214.mid',
#  'audio/0215.mid',
#  'audio/0216.mid',
#  'audio/0217.mid',
#  'audio/0218.mid',
#  'audio/0219.mid',
#  'audio/0220.mid',
#  'audio/0221.mid',
#  'audio/0222.mid',
#  'audio/0223.mid',
#  'audio/0224.mid',
#  'audio/0225.mid',
#  'audio/0226.mid',
#  'audio/0227.mid',
#  'audio/0228.mid',
#  'audio/0229.mid',
#  'audio/0230.mid',
#  'audio/0231.mid',
#  'audio/0232.mid',
#  'audio/0233.mid',
#  'audio/0234.mid',
#  'audio/0235.mid',
#  'audio/0236.mid',
#  'audio/0237.mid',
#  'audio/0238.mid',
#  'audio/0239.mid',
#  'audio/0240.mid',
#  'audio/0241.mid',
#  'audio/0242.mid',
#  'audio/0243.mid',
#  'audio/0244.mid',
#  'audio/0245.mid',
#  'audio/0246.mid',
#  'audio/0247.mid',
#  'audio/0248.mid',
#  'audio/0249.mid',
#  'audio/0250.mid',
#  'audio/0251.mid',
#  'audio/0252.mid',
#  'audio/0253.mid',
#  'audio/0254.mid',
#  'audio/0255.mid',
#  'audio/0256.mid',
#  'audio/0257.mid',
#  'audio/0258.mid',
#  'audio/0259.mid',
#  'audio/0260.mid',
#  'audio/0261.mid',
#  'audio/0262.mid',
#  'audio/0263.mid',
#  'audio/0264.mid',
#  'audio/0265.mid',
#  'audio/0266.mid',
#  'audio/0267.mid',
#  'audio/0268.mid',
#  'audio/0269.mid',
#  'audio/0270.mid',
#  'audio/0271.mid',
#  'audio/0272.mid',
#  'audio/0273.mid',
#  'audio/0274.mid',
#  'audio/0275.mid',
#  'audio/0276.mid',
#  'audio/0277.mid',
#  'audio/0278.mid',
#  'audio/0279.mid',
#  'audio/0280.mid',
#  'audio/0281.mid',
#  'audio/0282.mid',
#  'audio/0283.mid',
#  'audio/0284.mid',
#  'audio/0285.mid',
#  'audio/0286.mid',
#  'audio/0287.mid',
#  'audio/0288.mid',
#  'audio/0289.mid',
#  'audio/0290.mid',
#  'audio/0291.mid',
#  'audio/0292.mid',
#  'audio/0293.mid',
#  'audio/0294.mid',
#  'audio/0295.mid',
#  'audio/0296.mid',
#  'audio/0297.mid',
#  'audio/0298.mid',
#  'audio/0299.mid',
#  'audio/0300.mid',
#  'audio/0301.mid',
#  'audio/0302.mid',
#  'audio/0303.mid',
#  'audio/0304.mid',
#  'audio/0305.mid',
#  'audio/0306.mid',
#  'audio/0307.mid',
#  'audio/0308.mid',
#  'audio/0309.mid',
#  'audio/0310.mid',
#  'audio/0311.mid',
#  'audio/0312.mid',
#  'audio/0313.mid',
#  'audio/0314.mid',
#  'audio/0315.mid',
#  'audio/0316.mid',
#  'audio/0317.mid',
#  'audio/0318.mid',
#  'audio/0319.mid',
#  'audio/0320.mid',
#  'audio/0321.mid',
#  'audio/0322.mid',
#  'audio/0323.mid',
#  'audio/0324.mid',
#  'audio/0325.mid',
#  'audio/0326.mid',
#  'audio/0327.mid',
#  'audio/0328.mid',
#  'audio/0329.mid',
#  'audio/0330.mid',
#  'audio/0331.mid',
#  'audio/0332.mid',
#  'audio/0333.mid',
#  'audio/0334.mid',
#  'audio/0335.mid',
#  'audio/0336.mid',
#  'audio/0337.mid',
#  'audio/0338.mid',
#  'audio/0339.mid',
#  'audio/0340.mid',
#  'audio/0341.mid',
#  'audio/0342.mid',
#  'audio/0343.mid',
#  'audio/0344.mid',
#  'audio/0345.mid',
#  'audio/0346.mid',
#  'audio/0347.mid',
#  'audio/0348.mid',
#  'audio/0349.mid',
#  'audio/0350.mid',
#  'audio/0351.mid',
#  'audio/0352.mid',
#  'audio/0353.mid',
#  'audio/0354.mid',
#  'audio/0355.mid',
#  'audio/0356.mid',
#  'audio/0357.mid',
#  'audio/0358.mid',
#  'audio/0359.mid',
#  'audio/0360.mid',
#  'audio/0361.mid',
#  'audio/0362.mid',
#  'audio/0363.mid',
#  'audio/0364.mid',
#  'audio/0365.mid',
#  'audio/0366.mid',
#  'audio/0367.mid',
#  'audio/0368.mid',
#  'audio/0369.mid',
#  'audio/0370.mid',
#  'audio/0371.mid',
#  'audio/0372.mid',
#  'audio/0373.mid',
#  'audio/0374.mid',
#  'audio/0375.mid',
#  'audio/0376.mid',
#  'audio/0377.mid',
#  'audio/0378.mid',
#  'audio/0379.mid',
#  'audio/0380.mid',
#  'audio/0381.mid',
#  'audio/0382.mid',
#  'audio/0383.mid',
#  'audio/0384.mid',
#  'audio/0385.mid',
#  'audio/0386.mid',
#  'audio/0387.mid',
#  'audio/0388.mid',
#  'audio/0389.mid',
#  'audio/0390.mid',
#  'audio/0391.mid',
#  'audio/0392.mid',
#  'audio/0393.mid',
#  'audio/0394.mid',
#  'audio/0395.mid',
#  'audio/0396.mid',
#  'audio/0397.mid',
#  'audio/0398.mid',
#  'audio/0399.mid',
#  'audio/0400.mid',
#  'audio/0401.mid',
#  'audio/0402.mid',
#  'audio/0403.mid',
#  'audio/0404.mid',
#  'audio/0405.mid',
#  'audio/0406.mid',
#  'audio/0407.mid',
#  'audio/0408.mid',
#  'audio/0409.mid',
#  'audio/0410.mid',
#  'audio/0411.mid',
#  'audio/0412.mid',
#  'audio/0413.mid',
#  'audio/0414.mid',
#  'audio/0415.mid',
#  'audio/0416.mid',
#  'audio/0417.mid',
#  'audio/0418.mid',
#  'audio/0419.mid',
#  'audio/0420.mid',
#  'audio/0421.mid',
#  'audio/0422.mid',
#  'audio/0423.mid',
#  'audio/0424.mid',
#  'audio/0425.mid',
#  'audio/0426.mid',
#  'audio/0427.mid',
#  'audio/0428.mid',
#  'audio/0429.mid',
#  'audio/0430.mid',
#  'audio/0431.mid',
#  'audio/0432.mid',
#  'audio/0433.mid',
#  'audio/0434.mid',
#  'audio/0435.mid',
#  'audio/0436.mid',
#  'audio/0437.mid',
#  'audio/0438.mid',
#  'audio/0439.mid',
#  'audio/0440.mid',
#  'audio/0441.mid',
#  'audio/0442.mid',
#  'audio/0443.mid',
#  'audio/0444.mid',
#  'audio/0445.mid',
#  'audio/0446.mid',
#  'audio/0447.mid',
#  'audio/0448.mid',
#  'audio/0449.mid',
#  'audio/0450.mid',
#  'audio/0451.mid',
#  'audio/0452.mid',
#  'audio/0453.mid',
#  'audio/0454.mid',
#  'audio/0455.mid',
#  'audio/0456.mid',
#  'audio/0457.mid',
#  'audio/0458.mid',
#  'audio/0459.mid',
#  'audio/0460.mid',
#  'audio/0461.mid',
#  'audio/0462.mid',
#  'audio/0463.mid',
#  'audio/0464.mid',
#  'audio/0465.mid',
#  'audio/0466.mid',
#  'audio/0467.mid',
#  'audio/0468.mid',
#  'audio/0469.mid',
#  'audio/0470.mid',
#  'audio/0471.mid',
#  'audio/0472.mid',
#  'audio/0473.mid',
#  'audio/0474.mid',
#  'audio/0475.mid',
#  'audio/0476.mid',
#  'audio/0477.mid',
#  'audio/0478.mid',
#  'audio/0479.mid',
#  'audio/0480.mid',
#  'audio/0481.mid',
#  'audio/0482.mid',
#  'audio/0483.mid',
#  'audio/0484.mid',
#  'audio/0485.mid',
#  'audio/0486.mid',
#  'audio/0487.mid',
#  'audio/0488.mid',
#  'audio/0489.mid',
#  'audio/0490.mid',
#  'audio/0491.mid',
#  'audio/0492.mid',
#  'audio/0493.mid',
#  'audio/0494.mid',
#  'audio/0495.mid',
#  'audio/0496.mid',
#  'audio/0497.mid',
#  'audio/0498.mid',
#  'audio/0499.mid',
#  'audio/0500.mid',
#  'audio/0501.mid',
#  'audio/0502.mid',
#  'audio/0503.mid',
#  'audio/0504.mid',
#  'audio/0505.mid',
#  'audio/0506.mid',
#  'audio/0507.mid',
#  'audio/0508.mid',
#  'audio/0509.mid',
#  'audio/0510.mid',
#  'audio/0511.mid',
#  'audio/0512.mid',
#  'audio/0513.mid',
#  'audio/0514.mid',
#  'audio/0515.mid',
#  'audio/0516.mid',
#  'audio/0517.mid',
#  'audio/0518.mid',
#  'audio/0519.mid',
#  'audio/0520.mid',
#  'audio/0521.mid',
#  'audio/0522.mid',
#  'audio/0523.mid',
#  'audio/0524.mid',
#  'audio/0525.mid',
#  'audio/0526.mid',
#  'audio/0527.mid',
#  'audio/0528.mid',
#  'audio/0529.mid',
#  'audio/0530.mid',
#  'audio/0531.mid',
#  'audio/0532.mid',
#  'audio/0533.mid',
#  'audio/0534.mid',
#  'audio/0535.mid',
#  'audio/0536.mid',
#  'audio/0537.mid',
#  'audio/0538.mid',
#  'audio/0539.mid',
#  'audio/0540.mid',
#  'audio/0541.mid',
#  'audio/0542.mid',
#  'audio/0543.mid',
#  'audio/0544.mid',
#  'audio/0545.mid',
#  'audio/0546.mid',
#  'audio/0547.mid',
#  'audio/0548.mid',
#  'audio/0549.mid',
#  'audio/0550.mid',
#  'audio/0551.mid',
#  'audio/0552.mid',
#  'audio/0553.mid',
#  'audio/0554.mid',
#  'audio/0555.mid',
#  'audio/0556.mid',
#  'audio/0557.mid',
#  'audio/0558.mid',
#  'audio/0559.mid',
#  'audio/0560.mid',
#  'audio/0561.mid',
#  'audio/0562.mid',
#  'audio/0563.mid',
#  'audio/0564.mid',
#  'audio/0565.mid',
#  'audio/0566.mid',
#  'audio/0567.mid',
#  'audio/0568.mid',
#  'audio/0569.mid',
#  'audio/0570.mid',
#  'audio/0571.mid',
#  'audio/0572.mid',
#  'audio/0573.mid',
#  'audio/0574.mid',
#  'audio/0575.mid',
#  'audio/0576.mid',
#  'audio/0577.mid',
#  'audio/0578.mid',
#  'audio/0579.mid',
#  'audio/0580.mid',
#  'audio/0581.mid',
#  'audio/0582.mid',
#  'audio/0583.mid',
#  'audio/0584.mid',
#  'audio/0585.mid',
#  'audio/0586.mid',
#  'audio/0587.mid',
#  'audio/0588.mid',
#  'audio/0589.mid',
#  'audio/0590.mid',
#  'audio/0591.mid',
#  'audio/0592.mid',
#  'audio/0593.mid',
#  'audio/0594.mid',
#  'audio/0595.mid',
#  'audio/0596.mid',
#  'audio/0597.mid',
#  'audio/0598.mid',
#  'audio/0599.mid',
#  'audio/0600.mid',
#  'audio/0601.mid',
#  'audio/0602.mid',
#  'audio/0603.mid',
#  'audio/0604.mid',
#  'audio/0605.mid',
#  'audio/0606.mid',
#  'audio/0607.mid',
#  'audio/0608.mid',
#  'audio/0609.mid',
#  'audio/0610.mid',
#  'audio/0611.mid',
#  'audio/0612.mid',
#  'audio/0613.mid',
#  'audio/0614.mid',
#  'audio/0615.mid',
#  'audio/0616.mid',
#  'audio/0617.mid',
#  'audio/0618.mid',
#  'audio/0619.mid',
#  'audio/0620.mid',
#  'audio/0621.mid',
#  'audio/0622.mid',
#  'audio/0623.mid',
#  'audio/0624.mid',
#  'audio/0625.mid',
#  'audio/0626.mid',
#  'audio/0627.mid',
#  'audio/0628.mid',
#  'audio/0629.mid',
#  'audio/0630.mid',
#  'audio/0631.mid',
#  'audio/0632.mid',
#  'audio/0633.mid',
#  'audio/0634.mid',
#  'audio/0635.mid',
#  'audio/0636.mid',
#  'audio/0637.mid',
#  'audio/0638.mid',
#  'audio/0639.mid',
#  'audio/0640.mid',
#  'audio/0641.mid',
#  'audio/0642.mid',
#  'audio/0643.mid',
#  'audio/0644.mid',
#  'audio/0645.mid',
#  'audio/0646.mid',
#  'audio/0647.mid',
#  'audio/0648.mid',
#  'audio/0649.mid',
#  'audio/0650.mid',
#  'audio/0651.mid',
#  'audio/0652.mid',
#  'audio/0653.mid',
#  'audio/0654.mid',
#  'audio/0655.mid',
#  'audio/0656.mid',
#  'audio/0657.mid',
#  'audio/0658.mid',
#  'audio/0659.mid',
#  'audio/0660.mid',
#  'audio/0661.mid',
#  'audio/0662.mid',
#  'audio/0663.mid',
#  'audio/0664.mid',
#  'audio/0665.mid',
#  'audio/0666.mid',
#  'audio/0667.mid',
#  'audio/0668.mid',
#  'audio/0669.mid',
#  'audio/0670.mid',
#  'audio/0671.mid',
#  'audio/0672.mid',
#  'audio/0673.mid',
#  'audio/0674.mid',
#  'audio/0675.mid',
#  'audio/0676.mid',
#  'audio/0677.mid',
#  'audio/0678.mid',
#  'audio/0679.mid',
#  'audio/0680.mid',
#  'audio/0681.mid',
#  'audio/0682.mid',
#  'audio/0683.mid',
#  'audio/0684.mid',
#  'audio/0685.mid',
#  'audio/0686.mid',
#  'audio/0687.mid',
#  'audio/0688.mid',
#  'audio/0689.mid',
#  'audio/0690.mid',
#  'audio/0691.mid',
#  'audio/0692.mid',
#  'audio/0693.mid',
#  'audio/0694.mid',
#  'audio/0695.mid',
#  'audio/0696.mid',
#  'audio/0697.mid',
#  'audio/0698.mid',
#  'audio/0699.mid',
#  'audio/0700.mid',
#  'audio/0701.mid',
#  'audio/0702.mid',
#  'audio/0703.mid',
#  'audio/0704.mid',
#  'audio/0705.mid',
#  'audio/0706.mid',
#  'audio/0707.mid',
#  'audio/0708.mid',
#  'audio/0709.mid',
#  'audio/0710.mid',
#  'audio/0711.mid',
#  'audio/0712.mid',
#  'audio/0713.mid',
#  'audio/0714.mid',
#  'audio/0715.mid',
#  'audio/0716.mid',
#  'audio/0717.mid',
#  'audio/0718.mid',
#  'audio/0719.mid',
#  'audio/0720.mid',
#  'audio/0721.mid',
#  'audio/0722.mid',
#  'audio/0723.mid',
#  'audio/0724.mid',
#  'audio/0725.mid',
#  'audio/0726.mid',
#  'audio/0727.mid',
#  'audio/0728.mid',
#  'audio/0729.mid',
#  'audio/0730.mid',
#  'audio/0731.mid',
#  'audio/0732.mid',
#  'audio/0733.mid',
#  'audio/0734.mid',
#  'audio/0735.mid',
#  'audio/0736.mid',
#  'audio/0737.mid',
#  'audio/0738.mid',
#  'audio/0739.mid',
#  'audio/0740.mid',
#  'audio/0741.mid',
#  'audio/0742.mid',
#  'audio/0743.mid',
#  'audio/0744.mid',
#  'audio/0745.mid',
#  'audio/0746.mid',
#  'audio/0747.mid',
#  'audio/0748.mid',
#  'audio/0749.mid',
#  'audio/0750.mid',
#  'audio/0751.mid',
#  'audio/0752.mid',
#  'audio/0753.mid',
#  'audio/0754.mid',
#  'audio/0755.mid',
#  'audio/0756.mid',
#  'audio/0757.mid',
#  'audio/0758.mid',
#  'audio/0759.mid',
#  'audio/0760.mid',
#  'audio/0761.mid',
#  'audio/0762.mid',
#  'audio/0763.mid',
#  'audio/0764.mid',
#  'audio/0765.mid',
#  'audio/0766.mid',
#  'audio/0767.mid',
#  'audio/0768.mid',
#  'audio/0769.mid',
#  'audio/0770.mid',
#  'audio/0771.mid',
#  'audio/0772.mid',
#  'audio/0773.mid',
#  'audio/0774.mid',
#  'audio/0775.mid',
#  'audio/0776.mid',
#  'audio/0777.mid',
#  'audio/0778.mid',
#  'audio/0779.mid',
#  'audio/0780.mid',
#  'audio/0781.mid',
#  'audio/0782.mid',
#  'audio/0783.mid',
#  'audio/0784.mid',
#  'audio/0785.mid',
#  'audio/0786.mid',
#  'audio/0787.mid',
#  'audio/0788.mid',
#  'audio/0789.mid',
#  'audio/0790.mid',
#  'audio/0791.mid',
#  'audio/0792.mid',
#  'audio/0793.mid',
#  'audio/0794.mid',
#  'audio/0795.mid',
#  'audio/0796.mid',
#  'audio/0797.mid',
#  'audio/0798.mid',
#  'audio/0799.mid',
#  'audio/0800.mid',
#  'audio/0801.mid',
#  'audio/0802.mid',
#  'audio/0803.mid',
#  'audio/0804.mid',
#  'audio/0805.mid',
#  'audio/0806.mid',
#  'audio/0807.mid',
#  'audio/0808.mid',
#  'audio/0809.mid',
#  'audio/0810.mid',
#  'audio/0811.mid',
#  'audio/0812.mid',
#  'audio/0813.mid',
#  'audio/0814.mid',
#  'audio/0815.mid',
#  'audio/0816.mid',
#  'audio/0817.mid',
#  'audio/0818.mid',
#  'audio/0819.mid',
#  'audio/0820.mid',
#  'audio/0821.mid',
#  'audio/0822.mid',
#  'audio/0823.mid',
#  'audio/0824.mid',
#  'audio/0825.mid',
#  'audio/0826.mid',
#  'audio/0827.mid',
#  'audio/0828.mid',
#  'audio/0829.mid',
#  'audio/0830.mid',
#  'audio/0831.mid',
#  'audio/0832.mid',
#  'audio/0833.mid',
#  'audio/0834.mid',
#  'audio/0835.mid',
#  'audio/0836.mid',
#  'audio/0837.mid',
#  'audio/0838.mid',
#  'audio/0839.mid',
#  'audio/0840.mid',
#  'audio/0841.mid',
#  'audio/0842.mid',
#  'audio/0843.mid',
#  'audio/0844.mid',
#  'audio/0845.mid',
#  'audio/0846.mid',
#  'audio/0847.mid',
#  'audio/0848.mid',
#  'audio/0849.mid',
#  'audio/0850.mid',
#  'audio/0851.mid',
#  'audio/0852.mid',
#  'audio/0853.mid',
#  'audio/0854.mid',
#  'audio/0855.mid',
#  'audio/0856.mid',
#  'audio/0857.mid',
#  'audio/0858.mid',
#  'audio/0859.mid',
#  'audio/0860.mid',
#  'audio/0861.mid',
#  'audio/0862.mid',
#  'audio/0863.mid',
#  'audio/0864.mid',
#  'audio/0865.mid',
#  'audio/0866.mid',
#  'audio/0867.mid',
#  'audio/0868.mid',
#  'audio/0869.mid',
#  'audio/0870.mid',
#  'audio/0871.mid',
#  'audio/0872.mid',
#  'audio/0873.mid',
#  'audio/0874.mid',
#  'audio/0875.mid',
#  'audio/0876.mid',
#  'audio/0877.mid',
#  'audio/0878.mid',
#  'audio/0879.mid',
#  'audio/0880.mid',
#  'audio/0881.mid',
#  'audio/0882.mid',
#  'audio/0883.mid',
#  'audio/0884.mid',
#  'audio/0885.mid',
#  'audio/0886.mid',
#  'audio/0887.mid',
#  'audio/0888.mid',
#  'audio/0889.mid',
#  'audio/0890.mid',
#  'audio/0891.mid',
#  'audio/0892.mid',
#  'audio/0893.mid',
#  'audio/0894.mid',
#  'audio/0895.mid',
#  'audio/0896.mid',
#  'audio/0897.mid',
#  'audio/0898.mid',
#  'audio/0899.mid',
#  'audio/0900.mid',
#  'audio/0901.mid',
#  'audio/0902.mid',
#  'audio/0903.mid',
#  'audio/0904.mid',
#  'audio/0905.mid',
#  'audio/0906.mid',
#  'audio/0907.mid',
#  'audio/0908.mid',
#  'audio/0909.mid',
#  'audio/0910.mid',
#  'audio/0911.mid',
#  'audio/0912.mid',
#  'audio/0913.mid',
#  'audio/0914.mid',
#  'audio/0915.mid',
#  'audio/0916.mid',
#  'audio/0917.mid',
#  'audio/0918.mid',
#  'audio/0919.mid',
#  'audio/0920.mid',
#  'audio/0921.mid',
#  'audio/0922.mid',
#  'audio/0923.mid',
#  'audio/0924.mid',
#  'audio/0925.mid',
#  'audio/0926.mid',
#  'audio/0927.mid',
#  'audio/0928.mid',
#  'audio/0929.mid',
#  'audio/0930.mid',
#  'audio/0931.mid',
#  'audio/0932.mid',
#  'audio/0933.mid',
#  'audio/0934.mid',
#  'audio/0935.mid',
#  'audio/0936.mid',
#  'audio/0937.mid',
#  'audio/0938.mid',
#  'audio/0939.mid',
#  'audio/0940.mid',
#  'audio/0941.mid',
#  'audio/0942.mid',
#  'audio/0943.mid',
#  'audio/0944.mid',
#  'audio/0945.mid',
#  'audio/0946.mid',
#  'audio/0947.mid',
#  'audio/0948.mid',
#  'audio/0949.mid',
#  'audio/0950.mid',
#  'audio/0951.mid',
#  'audio/0952.mid',
#  'audio/0953.mid',
#  'audio/0954.mid',
#  'audio/0955.mid',
#  'audio/0956.mid',
#  'audio/0957.mid',
#  'audio/0958.mid',
#  'audio/0959.mid',
#  'audio/0960.mid',
#  'audio/0961.mid',
#  'audio/0962.mid',
#  'audio/0963.mid',
#  'audio/0964.mid',
#  'audio/0965.mid',
#  'audio/0966.mid',
#  'audio/0967.mid',
#  'audio/0968.mid',
#  'audio/0969.mid',
#  'audio/0970.mid',
#  'audio/0971.mid',
#  'audio/0972.mid',
#  'audio/0973.mid',
#  'audio/0974.mid',
#  'audio/0975.mid',
#  'audio/0976.mid',
#  'audio/0977.mid',
#  'audio/0978.mid',
#  'audio/0979.mid',
#  'audio/0980.mid',
#  'audio/0981.mid',
#  'audio/0982.mid',
#  'audio/0983.mid',
#  'audio/0984.mid',
#  'audio/0985.mid',
#  'audio/0986.mid',
#  'audio/0987.mid',
#  'audio/0988.mid',
#  'audio/0989.mid',
#  'audio/0990.mid',
#  'audio/0991.mid',
#  'audio/0992.mid',
#  'audio/0993.mid',
#  'audio/0994.mid',
#  'audio/0995.mid',
#  'audio/0996.mid',
#  'audio/0997.mid',
#  'audio/0998.mid',
#  'audio/0999.mid',
#  'audio/1000.mid',
#  ...]

# %% [markdown]
# ### **Function Definitions**

# %% [markdown]
# Define function to convert list to string

# %%
def listToString(listObj):

    # initialize an empty string
    stringText = ""

    # traverse in the string
    for element in listObj:
        stringText = stringText + " " + element

    # return string
    return stringText

# %% [markdown]
# Function to transpose a song to C maj if Major or A min if Minor

# %%
def transpose(song):
    #Transposes song to C maj/A min

    # get key using music21
    print("Ok")
    key = song.analyze("key")
    print(key,"Ok")
    # get interval for transposition. E.g., Bmaj -> Cmaj
    if key.mode == "major":
        intervalSong = interval.Interval(key.tonic, pitch.Pitch("C"))
    elif key.mode == "minor":
        intervalSong = interval.Interval(key.tonic, pitch.Pitch("A"))

    # transpose song by calculated interval
    tranposed_song = song.transpose(intervalSong)
    return tranposed_song

# %% [markdown]
# Function to check if rests are more than one bar length

# %%
#function to check if rest duration is acceptables
def isRestAcceptable(rest, timeSignature):
  #check is time signature denominator is 4
  if (timeSignature.denominator == 4):
      #if denominator 4, length of one bar is 4 beats
      barDuration = timeSignature.numerator
  #check is time signature denominator is 8
  elif (timeSignature.denominator == 8):
      #if denominator is 8, length of one bar is numerator/2
      barDuration = timeSignature.numerator/2.0
  #check is time signature denominator is 2
  elif (timeSignature.denominator == 2):
      #if denominator is 2, length of one bar is numerator * 2
      barDuration = timeSignature.numerator * 2.0
  else : barDuration = 0

  #return false if rest duration is greater than 2 bars
  if barDuration * 2 < rest.quarterLength:
      return False

  return True

# %% [markdown]
# Function to get bar in which 1st note occurs

# %%
def getStartingBar(score):
    for i in range(51):
        bar = score.measures(i-1,i)
        barflat = bar.flatten()
        for event in barflat:
            if isinstance(event, note.Note):
                num = i
                break
        else:
            continue
        break;
    return num

# %% [markdown]
# Define function to create midi data file

# %%
def createDatafile():
  #create a file named midiData.txt and append
  midiData_file = open("midiData.txt", "w")
#iterate over each midi file
  print("Writing midi data to file...")
  songCount = 0
  for file in songs:
    print("Processing " + str(file))
    print(file)
    try:
        midi = converter.parse(file) #convert to midi
    except:
        print("Error in parsing " + str(file))
        continue
    print("midi = ",midi)
    #midi = midi.stripTies()
    #tranpose song
    try:
        midi = transpose(midi)
    except:
        print("Error in obtaining key for " + str(file))
        continue
    #obtain 30 bars
    songTempo = ''
    try:
        firstbar = midi.measures(0,3)
        firstbarNotes = firstbar.flatten()
        for element in firstbarNotes:
            if isinstance(element, tempo.MetronomeMark):
                songTempo = str(element.number) + separator + "tempo"
        startBar = getStartingBar(midi)
        midi = midi.measures(startBar, startBar + 7)
    except Exception as e:
      print("Error in measures for " + str(file))
      continue
    midi = midi.flatten() #combine all parts and get a single notes part

    songCount += 1
    #initialize timeSignature, notes list and count variables
    timeSignature = ''
    notes = []
    #count = 0

    #loop over each midi event
    #midi events include timesignatures, instruments, notes, rests and chords
    for event in midi:
      #only obtain 50 events
      # if count == 50:
      #   break;
      # count += 1 #increase count
      #check if event is a timeSignature
      if isinstance(event, meter.TimeSignature ):
        #save time signature to file as '3/4@time'
        timeSignature = event.ratioString + separator + "time"
        timeSignatureEvent = event
      #check if event is a note
      if isinstance(event, note.Note):
        #save note to file as 'C1@0.5' where 'C1' is midi note and '0.5' is the duration
        notes.append(str(event.pitch) + separator + str(event.quarterLength))
      #check if event is a chord
      elif(isinstance(event, chord.Chord)):
        #save chord to file as '1.8.2@0.5' where '1.8.2' are notes in the chord and '0.5' is the duration
        notes.append(('.'.join(str(n) for n in event.normalOrder))+ separator + str(event.quarterLength))
      #check if event is a rest
      elif(isinstance(event, note.Rest)):
        #check if rest duration is acceptable
        if isRestAcceptable(event, timeSignatureEvent):
          #save rest as 'r@0.5' where 'r' indicates that it is a rest and '0.5'  is the duration
          notes.append('r' + separator + str(event.quarterLength))

    #save the sequence to the file
    # jpgFilenamesList = glob(data_dir + 'images/' + os.path.basename(file).split('.')[0] + '*.*')
    jpgFilenamesList = ['image/' + os.path.basename(file).split('.')[0] + '.jpg']
    #jpgFilenamesList = glob(
    simImageCount = 0
    for image in jpgFilenamesList:
        simImageCount += 1
        #first write the file id which is same as the image id
        sequence = os.path.basename(image).split('.')[0] + " " + "<start> " + songTempo + " " + timeSignature + listToString(notes) + " <end>" #append <start> and <end> tokens
        #if current song is the last in the list, don't add a newline character to the end
        if((len(songs)== songs.index(file) +1) and simImageCount == len(jpgFilenamesList)):
            pass
        else:
            sequence = sequence + "\n"
        midiData_file.write(sequence)

  print(f"Finishes writing midi data. {songCount} songs written.")
  #close file
  midiData_file.close()

# %% [markdown]
# Function to load a file

# %%
def load_file(fileName):
  """

  Args:
    fileName:

  Returns:
    content:

  """
  #open file in read mode
  file = open(fileName, 'r')
  #obtain content in file
  content = file.read()
  #close file
  file.close()

  return content

# %% [markdown]
# Function to map file content to dict, create vocabulary and obtain max length of a midi sequence

# %%
def dict_vocab_maxLength(content):
  #initialize dictionary
  midiDict = dict()
  vocabulary = set()
  maxLength = 0
  #loop over each line in content -> each midi song is separated by new line
  for line in content.split('\n'):
    #split line into tokens by white space
    tokens = line.split()
    #first token is image id, rest are midi events
    imageId, midi = tokens[0], tokens[1:]
    #create a list if not created
    if imageId not in midiDict:
      midiDict[imageId] = list()
    midiDict[imageId].append(midi)
    #build vocabulary
    vocabulary.update(midi)
    #store max length
    if len(tokens) > maxLength:
      maxLength = len(tokens)
  #return dict, vocabulary and maxlength
  return midiDict, vocabulary, maxLength

# %% [markdown]
# Function to tokenize vocabulary and return tokenizer

# %%
def tokenize(vocab):
  #filter 50 midi events with low frequency
  num_words= len(vocab) - 10
  #initialize tokenizer object without any filters
  tokenizer = Tokenizer(num_words=num_words, filters='')
  #generate tokens
  tokenizer.fit_on_texts(vocab)
  print("Number of tokens: " + str(len(tokenizer.word_index)))
  return tokenizer

# %% [markdown]
# ### **Midi Preprocessing steps**

# %% [markdown]
# Create a text file with all midi data of all songs

# %%
# createDatafile()

# %% [markdown]
# Load Saved file

# %%
content = load_file("midiData.txt")

# %% [markdown]
# Create a Dictionary with midi data, obtain vocabulary and get the max length of a midi sequence

# %%
train_midi, vocabulary, maxLength = dict_vocab_maxLength(content)
#print vocabulary length
vocabSize = len(vocabulary) + 1
print("Vocabulary length = " + str(vocabSize))
#print max length of sequence
print("Maximum length sequence = " + str(maxLength))
print(train_midi['0001'])
print(vocabulary)
# maxLength
# Out:
# Vocabulary length = 978
# Maximum length sequence = 236
# [['<start>', '114.0@tempo', '4/4@time', '4@0.25', '0.4.7@0.25', 'E5@1.0', '0.4.7@1.0', '4@0.75', '4@1.0', '2@0.25', '2@0.75', '2.4.8@1.0', '2@0.25', '2.4.8@0.75', 'E5@1.0', '2.4.8@0.25', '2@0.75', '9@1.0', '0@0.25', '0@0.75', '9.0.4@1.0', '0@0.25', 'r@1.5', 'r@1.0', '9.0.4@1.0', 'A4@1/3', '5@0.75', 'D5@1/3', 'r@1/6', 'F5@0.25', 'r@2/3', 'r@0.25', '5@0.25', 'A5@1/3', '2.5.9@1.0', 'D6@1/3', 'r@1/6', 'F6@0.25', 'r@1/6', 'r@0.25', 'r@1.5', 'A6@1.0', '2.5.9@1.0', 'E4@1/3', '7@1.0', 'G4@1/3', 'r@1/6', 'C5@0.25', 'r@2/3', 'r@0.25', 'E5@1/3', '0.4.7@0.75', 'G5@1/3', 'r@1/6', 'C6@0.25', 'r@1/6', 'r@0.25', 'r@2.5', '0.4.7@0.25', 'E6@1.0', '0.4.7@1.0', 'D6@0.5', '7@1.0', 'r@0.5', 'G5@1/3', '5.7.11@1.0', 'D6@1/3', 'r@1/6', 'G6@0.25', 'r@1/6', 'r@0.25', 'r@0.5', 'G5@1/3', '5.7.11@0.75', 'D6@1/3', 'r@1/6', 'G6@0.25', 'r@13/6', 'r@0.25', '5.7.11@0.25', 'C6@1.75', 'C3@1.0', '0.4.7@1.0', 'r@1.25', 'r@1.5', 'C6@0.25', '0.4.7@1.0', 'A4@1/3', '5@0.75', 'D5@1/3', 'r@1/6', 'F5@0.25', 'r@2/3', 'r@0.25', '5@0.25', 'A5@1/3', '2.5.9@1.0', 'D6@1/3', 'r@1/6', 'F6@0.25', 'r@1/6', 'r@0.25', 'r@1.5', 'A6@1.0', '2.5.9@1.0', 'E4@1/3', '7@1.0', 'G4@1/3', 'r@1/6', 'C5@0.25', 'r@2/3', 'r@0.25', 'E5@1/3', '0.4.7@0.75', 'G5@1/3', 'r@1/6', 'C6@0.25', 'r@1/6', '0.4.7@0.25', '0.4.7@1.0', '7@1.0', '4.5.7@1.0', '4.5.7@0.75', '4.5.7@0.25', '0@1/3', 'r@41/12', '<end>']]
# {'B1@0.25', '7.0@1.0', 'C7@1/3', '2.5.9@0.5', '100.0@tempo', 'G1@1/3', 'B2@1/3', '4@1.0', '0.4.7@0.75', 'E3@1/3', '5@2.0', 'C2@0.5', 'F5@1.0', 'G3@3.0', '9@1.0', '2.6@0.25', '7.0@1.5', '1.6@1.0', '2.6@1.0', 'A5@0.5', 'A-5@1.0', 'G5@1/3', 'G#4@1.0', '5.8.0@0.25', 'G4@1/3', '0.3.6.9@1.0', 'E-5@0.25', '4.9@1.0', 'B-3@1.75', 'E3@2.0', '7.11.2@3.0', 'E-5@1.0', 'C2@1/3', 'A4@1.5', '100.5@tempo', '4.8.11@3.0', 'E6@1.0', 'C2@3.25', 'D5@0.75', '5.9.0@2.75', '10@1.0', 'A5@0.25', 'r@4/3', 'r@1/6', '11.4@1/3', 'E3@1.0', '2.6.9@0.75', '4.5@0.25', '2.8@3.75', 'G3@1/3', '8.11.2.4@0.25', 'D2@1/3', '4.7.9@0.25', 'E3@2.5', '9.0.2.5@2.0', 'A3@0.5', '11@2.25', 'E3@43/12', '11@0.25', 'E3@1.5', '7.11@0.5', '1.4@0.25', '4@0.75', 'B5@1.0', 'B5@0.25', '2.6@1/3', '4.8.11@1.5', 'G2@1.0', '80.0@tempo', 'D1@0.5', 'E5@1.5', '9@3.75', 'C#4@3.75', 'B5@0.5', 'r@2/3', '0.3.6.9@2.75', 'A1@1/12', 'G4@0.25', 'G2@0.25', '7.11.2@1.0', 'E4@1/6', 'E6@1/3', '5.9@0.25', 'A2@0.5', 'B3@1.5', 'C3@1.25', '9.2@0.25', '2.5@1/12', 'E1@0.75', 'A-2@0.25', '9@0.75', '9.0.4@2.5', 'C3@0.5', '4.9@0.75', 'C#5@0.75', 'A4@0.75', 'E4@1/12', '0.2@0.5', 'B4@1.25', 'E4@1/3', '6.9.11@1.0', '4.9@1/3', '7@0.25', '0.5@1.5', '10.2@0.5', 'A-4@1/3', '10.3@0.5', '4.8.11@1.0', '9.0@1.25', '11.2@1.25', 'F6@1/3', 'E2@0.25', '9@2/3', '4@3.75', '108.0@tempo', 'G4@1.0', 'E-6@0.25', 'G3@1.25', 'C3@1.5', '0.4.7@4.0', 'F2@1/6', '4.7@2.0', 'A6@0.25', '0.4.7@4/3', '0@1.25', '11.2@1/6', '4.10@0.25', '4@1.75', '5.9.0@1.5', 'F3@0.5', '4@5/3', '0.2.7@2/3', '9@0.25', '1@0.25', '3@0.5', 'G#3@1.5', '1.5@2.0', '2.7@0.25', '5@1.0', '11.2@0.25', '0.4.7@1.5', 'F#2@0.5', 'A3@1.0', '150.0@tempo', '160.0@tempo', 'E-4@1.75', '1.4.7.9@2.0', 'F#3@0.5', 'B3@1.0', '168.0@tempo', '5.7@1.0', 'E5@4.0', 'G3@1.5', 'B-4@0.75', 'G6@1/3', '4.7.10.0@0.5', 'r@0.5', '1.4.7@0.5', 'F1@1/3', '8.11.2@1.0', '70.0@tempo', '9.0.4@2.75', '7.11@2.25', '4@0.5', '9.0@0.5', 'A3@1.25', 'A2@2.75', 'B-4@0.5', 'F4@4.0', '9@2.0', 'D6@2/3', '7.10.1@1.0', 'r@5/3', '0@1.0', 'E3@5/6', 'E-3@2.0', '6@0.75', 'C7@0.25', 'E6@0.5', '4@1.5', '2.4.8@1.0', 'B4@1/3', '5.7.0@0.75', 'F#4@0.5', 'F2@1/3', '2.4.6.9@0.5', 'F#2@2.75', '0.4@1/12', '9.0@2.75', 'F#5@1.0', '4.9@2.0', 'E6@2.0', '4.7.10.0@1.5', 'r@2.25', '4.7.9@0.75', '4.6.8.0@1.5', '9.1.4@1.0', 'G4@1.5', '132.0@tempo', '2@1.25', 'A3@1.5', 'A2@3.0', '5@0.75', 'G#5@0.25', 'B6@0.25', 'G#4@0.5', 'G2@2.75', '2.7@1/3', '5.10@0.25', 'C6@1/3', 'B3@0.5', '1.5@0.25', '0@2.75', 'A-5@0.25', 'D3@1.5', 'r@8/3', 'B-3@0.5', 'C#2@0.25', '0@1/3', '154.0@tempo', 'C1@1/3', '1.5@0.75', 'E-3@0.5', '1.5.8@0.25', '6.9.0@1.5', 'D2@1.75', 'E7@4/3', '4.9@3.0', '5.9@1.0', '4.7@29/12', 'B4@1/6', '2.6.9@1.5', 'E4@0.75', '3.4.5.6.7.8@0.25', '7.9.1@1.0', '2.4.9@0.5', '6@0.5', '1.7@0.5', '1.5.8@1.5', 'r@11/6', '4.8@0.75', 'C#5@1.5', 'C4@1.0', 'C#5@0.25', 'r@19/6', '9.0.2.5@1.0', '4.9@1.5', '2@0.5', '96.0@tempo', 'C6@1.75', 'E4@2.0', 'r@1/12', 'C4@1.25', '6.9@0.75', 'D6@1/3', '4.7@4.0', 'B5@4.0', 'E1@2.0', 'G#5@1/3', '7.11.2@2.0', '5@0.25', '11.4@1.0', '2.6.9@0.25', 'G#3@1.25', 'r@11/12', 'A2@3.75', '11.2@1/3', '11@1.0', '170.0@tempo', '4.5@0.5', 'E2@0.5', '6.9.1@0.5', 'E5@2.25', 'D2@2.0', 'E-4@1/3', '11.2.5.7@0.75', '6.9@0.5', 'E3@0.5', 'E5@43/12', '8.0@0.5', 'C#6@1/12', '9@0.5', '4.7.10@0.25', 'G3@1/6', 'E1@1.0', '4.7.11@0.5', '9.0@1/3', 'D7@0.5', '8.11@0.5', 'B2@1.0', 'F#5@0.25', '7.0@0.5', '2.5@2.0', '9.0@0.25', '11.2.5@1.0', 'F1@1.0', 'r@1.25', '11@1/3', '75.0@tempo', 'F1@0.25', 'B-1@0.5', '7@1.5', 'C5@3.0', 'E-4@1.0', '0.5@1.0', '3@0.25', 'G5@0.25', 'D1@1/3', 'B-2@0.25', 'A1@1/3', 'C5@0.5', '9.0.2@2/3', 'B-4@0.25', '78.0@tempo', '2@0.25', '2.4.9@1.0', '1.2@0.25', 'E2@1.25', '11.2@0.5', '110.0@tempo', '0.2.7@1.5', '9.0@2.0', '3/4@time', '2.7@0.75', 'A3@0.0', '5.7@0.5', '4.7@0.25', '5.7.11@0.25', 'B2@1.5', 'B3@1/12', '<start>', 'D4@2.75', 'B4@1.0', '85.0@tempo', '4.8.10@0.5', '9.0.4@1.0', 'F2@0.75', '11.2.5@1.5', '4.6.10.0@0.25', '2.5.9@2.0', 'E4@0.25', '0.6@37/12', '8.11@1/12', 'B2@0.5', 'E-6@0.5', '5.8.11@1.0', '0@2.0', 'D3@2.0', '4.5.7@0. ...

# %% [markdown]
# Tokenize vocabulary and save tokenizer pickle

# %%
# tokenizer = tokenize(vocabulary)
import tensorflow.keras
tokenizer = load(open('tokenizer.pkl', 'rb'))

# %%
tokenizer.word_index
# Out:
# {'0@7/6': 1,
#  'c3@0.75': 2,
#  'g4@0.75': 3,
#  '5@1/12': 4,
#  '168@tempo': 5,
#  'd4@1.5': 6,
#  'c6@0.5': 7,
#  '1.4.7.9@0.5': 8,
#  'e1@0.75': 9,
#  'e-2@0.25': 10,
#  '8.0.3@1.5': 11,
#  '9@1/3': 12,
#  'g#3@1.25': 13,
#  '6.9.11@1.5': 14,
#  'g4@2.25': 15,
#  '5.8.11@1.0': 16,
#  '7.9.2@1.75': 17,
#  'g2@0.75': 18,
#  '6.9.11@1.0': 19,
#  '2.4.8@0.5': 20,
#  '7.9@0.25': 21,
#  'b5@1.0': 22,
#  '0.4.5@1.0': 23,
#  '10.0.5@2.0': 24,
#  'a5@2.0': 25,
#  'f3@1.5': 26,
#  '8.11@0.25': 27,
#  'r@7/3': 28,
#  '4.7.10@0.75': 29,
#  '11.2@1/6': 30,
#  'f4@1/3': 31,
#  '3@0.5': 32,
#  '2.6@0.25': 33,
#  '4@3.25': 34,
#  'a6@0.5': 35,
#  'c#2@0.5': 36,
#  'b-1@0.5': 37,
#  '11.2.4@2/3': 38,
#  '0@1.5': 39,
#  '11@0.25': 40,
#  'd3@0.25': 41,
#  '1.6@1.0': 42,
#  'b-5@0.5': 43,
#  '128@tempo': 44,
#  'r@0.75': 45,
#  'c#4@0.5': 46,
#  'f#2@0.25': 47,
#  '11@0.5': 48,
#  '2.4.8@1.0': 49,
#  'f3@1/3': 50,
#  '92@tempo': 51,
#  '3.5.10@1.0': 52,
#  'a2@3.75': 53,
#  '11.4@1.0': 54,
#  '9.0@3.0': 55,
#  '184@tempo': 56,
#  'a-4@1.0': 57,
#  'd7@0.5': 58,
#  '135@tempo': 59,
#  '9@1.0': 60,
#  'c5@0.75': 61,
#  '7@1.0': 62,
#  '2@1.25': 63,
#  'e-3@1.75': 64,
#  'r@1/6': 65,
#  'e5@1.25': 66,
#  'e-3@0.5': 67,
#  '11.2@1/3': 68,
#  '9.2@3.75': 69,
#  '11.0.4.7@0.75': 70,
#  'd6@0.25': 71,
#  'c4@1/3': 72,
#  '2.6.9@0.75': 73,
#  'g#2@2.0': 74,
#  '0.6@37/12': 75,
#  '6.8.0@1.5': 76,
#  '0.4.7@0.25': 77,
#  '8.0@19/6': 78,
#  'f#2@2.75': 79,
#  '11.2.5.7@3.0': 80,
#  '0.4.7@2.75': 81,
#  '9@2.5': 82,
#  '11.2.4.7@1.0': 83,
#  '11.0.4@1.0': 84,
#  '2.4.9@0.5': 85,
#  '7@0.75': 86,
#  'a5@0.75': 87,
#  '4.7.11@0.5': 88,
#  '2.5.9@0.5': 89,
#  '4.9@1.5': 90,
#  '90@tempo': 91,
#  'a4@2.5': 92,
#  '0.3.5@2.0': 93,
#  'f2@0.75': 94,
#  '9.11.4@4.0': 95,
#  'e5@1.5': 96,
#  '0.5@1/3': 97,
#  'r@19/6': 98,
#  '0.3.6.9@2.75': 99,
#  'd3@2.75': 100,
#  '3/4@time': 101,
#  '0.4.7@2.25': 102,
#  'e4@1.25': 103,
#  '7@2.5': 104,
#  'f5@0.5': 105,
#  '10.2@0.5': 106,
#  '9.1.4@0.5': 107,
#  'g#4@1.0': 108,
#  'd3@1/3': 109,
#  '9.11@0.25': 110,
#  '9.0.4@0.25': 111,
#  'd6@1.0': 112,
#  'g#4@0.25': 113,
#  '2.6.9@2.0': 114,
#  '9.11.4@1.5': 115,
#  'd5@0.25': 116,
#  'c6@1.75': 117,
#  '145@tempo': 118,
#  'a3@2.0': 119,
#  'c#6@0.25': 120,
#  'f3@1.0': 121,
#  'd2@1.75': 122,
#  '11.0.4.7@1.5': 123,
#  'c4@1.0': 124,
#  '0.2@0.25': 125,
#  '7.0@2.0': 126,
#  'a5@1.25': 127,
#  'f5@2.0': 128,
#  'f2@2.0': 129,
#  'e4@1.0': 130,
#  'a-3@1.0': 131,
#  '11@1.5': 132,
#  'c#4@3.75': 133,
#  '5.7.11@0.25': 134,
#  'e3@1.75': 135,
#  'e3@2.0': 136,
#  '0.4@4/3': 137,
#  'f4@1.0': 138,
#  'r@5/3': 139,
#  'r@2.0': 140,
#  '4.7.11@4.0': 141,
#  'c6@0.75': 142,
#  'r@4.0': 143,
#  'g4@1.0': 144,
#  'f#3@0.5': 145,
#  '9.0.4@2.0': 146,
#  'f3@2.0': 147,
#  '5.7.0@5/12': 148,
#  'c3@1.25': 149,
#  'd3@2.0': 150,
#  'c4@2.75': 151,
#  '0.2.7@2/3': 152,
#  'b-2@2.0': 153,
#  '4@0.5': 154,
#  '6.9@0.5': 155,
#  'a4@0.25': 156,
#  'a5@0.0': 157,
#  'g3@1/3': 158,
#  '5.10@1.0': 159,
#  'e-6@0.5': 160,
#  '11.2@0.25': 161,
#  '4@1/3': 162,
#  '2.8@0.5': 163,
#  '7.11@2.0': 164,
#  '2.5@0.75': 165,
#  '7@2.75': 166,
#  'b6@1/3': 167,
#  '6@0.5': 168,
#  '2.5@1/3': 169,
#  '9.11.4@2.0': 170,
#  'a2@3.0': 171,
#  '0.4@0.25': 172,
#  'g5@1.0': 173,
#  'a-5@1.0': 174,
#  '185@tempo': 175,
#  '2.5@0.5': 176,
#  'e4@0.75': 177,
#  '9@2.0': 178,
#  '4.9@3.75': 179,
#  'g4@1.5': 180,
#  '6.9.0.2@0.5': 181,
#  '1@0.25': 182,
#  'a-3@0.25': 183,
#  '3.5@0.5': 184,
#  '7.11@1.0': 185,
#  'c5@0.0': 186,
#  'g5@0.25': 187,
#  '3.7@1/3': 188,
#  '0.2.7@0.25': 189,
#  'c#5@0.25': 190,
#  'e3@0.5': 191,
#  'e4@0.5': 192,
#  '9.11@1/3': 193,
#  'f1@0.5': 194,
#  '70@tempo': 195,
#  '0.4@1.5': 196,
#  'b-3@0.25': 197,
#  '5.9.0@3.0': 198,
#  '11.2@2.0': 199,
#  'a3@1/3': 200,
#  'c3@1.0': 201,
#  'g#4@2.75': 202,
#  '144@tempo': 203,
#  '0.4.5@0.5': 204,
#  '9.0@1.25': 205,
#  'f#3@0.25': 206,
#  '2.7@4/3': 207,
#  '2.5.7@0.25': 208,
#  '1.4@0.25': 209,
#  '154@tempo': 210,
#  '0.2.7@1.0': 211,
#  'r@5/12': 212,
#  'e-5@1.0': 213,
#  'e1@3.25': 214,
#  '9@0.25': 215,
#  '5.8.0@1.0': 216,
#  '7@0.5': 217,
#  '10.1@1.0': 218,
#  '11.4@1/3': 219,
#  'g5@1/3': 220,
#  '4@1.75': 221,
#  '4.7@0.75': 222,
#  'f1@1.0': 223,
#  '4.6.8.0@1.5': 224,
#  '0.4@1/3': 225,
#  'e6@1.0': 226,
#  '5.7@1.0': 227,
#  '5.7@0.5': 228,
#  'e5@1/3': 229,
#  '2.4@0.5': 230,
#  '7.11.2@0.75': 231,
#  '2.8@3.75': 232,
#  'g3@2.0': 233,
#  '0.4.7@0.75': 234,
#  '5@2.0': 235,
#  'g2@2.75': 236,
#  'a4@2.0': 237,
#  'r@8/3': 238,
#  '5.7.10@1.5': 239,
#  '<start>': 240,
#  '2.4.6.9@0.5': 241,
#  '5.7.11@0.75': 242,
#  'e3@2.5': 243,
#  '1.4.8@1.0': 244,
#  'g#4@0.75': 245,
#  'd6@2/3': 246,
#  '4@0.75': 247,
#  '0.4.7@1.0': 248,
#  'g4@2.0': 249,
#  'f#2@1.0': 250,
#  '4@2.0': 251,
#  'c#3@0.25': 252,
#  'r@1.25': 253,
#  'f2@1/6': 254,
#  'c5@3.0': 255,
#  'a3@1.0': 256,
#  '7@0.25': 257,
#  'f5@2.25': 258,
#  'g3@1.75': 259,
#  '9@2/3': 260,
#  'r@17/6': 261,
#  '6.9.1@0.5': 262,
#  'g3@2.75': 263,
#  'b4@0.5': 264,
#  '4@0.25': 265,
#  'r@0.5': 266,
#  'f5@1.0': 267,
#  'b5@0.5': 268,
#  'f2@1.0': 269,
#  '9.0.4@2.75': 270,
#  'b3@1/3': 271,
#  'f6@0.25': 272,
#  'r@41/12': 273,
#  'c2@0.5': 274,
#  '7.0@1/6': 275,
#  '4.6@1.0': 276,
#  'f#2@0.5': 277,
#  '7.11@1/3': 278,
#  'd6@1/3': 279,
#  '9.0@0.25': 280,
#  '165@tempo': 281,
#  'g6@3.0': 282,
#  '7.10@0.5': 283,
#  '9.2@0.25': 284,
#  'b3@0.0': 285,
#  'e-4@1.75': 286,
#  '2@1.5': 287,
#  '0.4@2.0': 288,
#  'c3@2.0': 289,
#  '8.0@0.5': 290,
#  '2.3@0.25': 291,
#  '7.11@0.5': 292,
#  'e-2@0.75': 293,
#  '100@tempo': 294,
#  'b3@1.0': 295,
#  '4.7@1/3': 296,
#  'e-4@1/3': 297,
#  '11.2.5.7@2.75': 298,
#  'b2@1.5': 299,
#  '0.5@0.25': 300,
#  '4.5.7@0.25': 301,
#  'b-3@1.75': 302,
#  'a4@0.5': 303,
#  'b1@1/3': 304,
#  'f2@0.5': 305,
#  '4.7@1.0': 306,
#  '1@0.5': 307,
#  'a4@1.0': 308,
#  '2.6.9@1.5': 309,
#  '4.7.9@0.25': 310,
#  '108@tempo': 311,
#  '9.0.4@1.5': 312,
#  '11.2.5@1.0': 313,
#  '4.6.9.11@1.0': 314,
#  '6@0.75': 315,
#  '0.5@1.0': 316,
#  '10@0.5': 317,
#  '80@tempo': 318,
#  '5.9.0@1.5': 319,
#  'c6@0.25': 320,
#  '0.2@1/3': 321,
#  'b-4@1.0': 322,
#  '0.5@0.5': 323,
#  '5@0.5': 324,
#  'd5@1.0': 325,
#  '4.7.10.0@0.5': 326,
#  '11.3@0.5': 327,
#  'g#4@2.0': 328,
#  '11.4@0.25': 329,
#  '0@7/3': 330,
#  'e1@1.0': 331,
#  '9.0@0.5': 332,
#  'e5@2.0': 333,
#  'g3@1.0': 334,
#  '9.0.4@2.5': 335,
#  '10@1/3': 336,
#  '7.11.2@1.5': 337,
#  'r@19/12': 338,
#  '6.10.1@1.0': 339,
#  '7.10@0.25': 340,
#  '0@0.5': 341,
#  'f5@0.25': 342,
#  'c2@1.0': 343,
#  '4.9@1/3': 344,
#  'f#6@0.25': 345,
#  'a4@1.25': 346,
#  'g#3@0.5': 347,
#  '4.6.11@1.5': 348,
#  'f2@0.25': 349,
#  '132@tempo': 350,
#  '1.4.7@0.5': 351,
#  'e6@1/3': 352,
#  '9.0@2.0': 353,
#  'a1@0.5': 354,
#  '2.5@2.0': 355,
#  'e-2@1.0': 356,
#  'g2@1.0': 357,
#  '7.0@1.5': 358,
#  'e2@2.0': 359,
#  '11.2@1.25': 360,
#  'e4@1.5': 361,
#  'a4@1.5': 362,
#  'e-2@0.5': 363,
#  '8.11.2@2.75': 364,
#  'g2@1/6': 365,
#  'r@1/3': 366,
#  '6@0.25': 367,
#  '3@0.25': 368,
#  'a5@2/3': 369,
#  '4.7@0.25': 370,
#  'f#2@2.0': 371,
#  'b4@1/3': 372,
#  '7.9@1/3': 373,
#  '1.6@0.5': 374,
#  '7.11@0.25': 375,
#  'e4@0.25': 376,
#  '4.7@4.0': 377,
#  'd3@1.0': 378,
#  '0.5@2.0': 379,
#  'g4@0.0': 380,
#  '4@1.0': 381,
#  '7.0@0.5': 382,
#  '9.0.2@1/3': 383,
#  '7.0@0.25': 384,
#  '5.9.0@2.75': 385,
#  '1.5.8@1.5': 386,
#  'b5@1.25': 387,
#  '0.4.7@3.0': 388,
#  '5.10@0.25': 389,
#  'r@3.75': 390,
#  'a4@0.75': 391,
#  '7.11.2@2.0': 392,
#  '1.5@0.5': 393,
#  'c1@3.25': 394,
#  '7.0@3.0': 395,
#  '0.4@0.75': 396,
#  '9.0.4@0.5': 397,
#  'a5@1/12': 398,
#  'g4@0.25': 399,
#  '4.8.11@1.5': 400,
#  'r@2.5': 401,
#  'c5@0.5': 402,
#  'e2@1.25': 403,
#  '167@tempo': 404,
#  'e6@0.5': 405,
#  'a1@0.25': 406,
#  '5@0.25': 407,
#  '0@2.75': 408,
#  '75@tempo': 409,
#  'e5@4/3': 410,
#  '10@2.25': 411,
#  'e3@1.0': 412,
#  'e-3@0.25': 413,
#  '9.0.3@1.0': 414,
#  'd3@1.5': 415,
#  '5.7.0@0.5': 416,
#  'e2@0.5': 417,
#  'g4@1/3': 418,
#  'd5@1.5': 419,
#  'e-3@2.0': 420,
#  '4@1/12': 421,
#  '5.7.0@1/3': 422,
#  'd4@2.75': 423,
#  'r@11/6': 424,
#  '0.2.7@1.5': 425,
#  '7@2/3': 426,
#  '140@tempo': 427,
#  '8.9.10.11.0.1@0.25': 428,
#  '2@1.0': 429,
#  '2@0.25': 430,
#  '2.6.9@1.0': 431,
#  '0.5@1.5': 432,
#  'e2@1.0': 433,
#  'g2@0.25': 434,
#  'c3@1/3': 435,
#  'g#2@0.25': 436,
#  '7.9.2@2.0': 437,
#  '9@1/12': 438,
#  '8@1.0': 439,
#  '4.6.10.0@1.75': 440,
#  '95@tempo': 441,
#  'f6@1/3': 442,
#  'g2@1/3': 443,
#  '11@1/3': 444,
#  'f#4@0.5': 445,
#  'g#4@1/3': 446,
#  'f1@0.25': 447,
#  'b4@1.25': 448,
#  'r@11/12': 449,
#  '8.0.3@0.25': 450,
#  'b-2@0.25': 451,
#  'g6@0.5': 452,
#  '2.5.9@1.0': 453,
#  '4.9@0.75': 454,
#  '7.11.2@1.0': 455,
#  '5.7.11@1/3': 456,
#  '5@0.75': 457,
#  '0.2@0.5': 458,
#  'd4@3.0': 459,
#  '2.5.7.10@2.0': 460,
#  '11.2.5.7@1.0': 461,
#  'e3@1.5': 462,
#  '4.7.10.0@1.5': 463,
#  '5@1.0': 464,
#  'd2@1.5': 465,
#  '8.0@1/6': 466,
#  '10.1@0.5': 467,
#  '1.5@0.75': 468,
#  'd5@3.5': 469,
#  'c7@0.25': 470,
#  'c5@1.0': 471,
#  '5.9.0@0.75': 472,
#  '1.5.8@0.25': 473,
#  '2@1/3': 474,
#  '6.11@0.5': 475,
#  'f#5@1.0': 476,
#  '11@1.0': 477,
#  '4.7.9.0@1.0': 478,
#  '2.8@1/3': 479,
#  'r@7/6': 480,
#  'c2@1/3': 481,
#  'b-3@0.5': 482,
#  '78@tempo': 483,
#  '7.11.2@2.5': 484,
#  'e2@0.25': 485,
#  'c2@2.0': 486,
#  '2.5@0.25': 487,
#  'b4@2.0': 488,
#  'd5@2.0': 489,
#  '4.5@0.25': 490,
#  'e-4@1.0': 491,
#  'e1@2.0': 492,
#  'r@29/12': 493,
#  'g1@0.25': 494,
#  'f4@4.0': 495,
#  '0.2.7@0.5': 496,
#  'g6@1/3': 497,
#  '4.7@0.5': 498,
#  '2/2@time': 499,
#  'b4@1/6': 500,
#  '9.0@0.75': 501,
#  '9@3.75': 502,
#  '10.0@1/3': 503,
#  '2.6.9@3.0': 504,
#  'a5@1.0': 505,
#  'b4@1.75': 506,
#  'g4@0.5': 507,
#  'e3@5/3': 508,
#  'e-1@0.5': 509,
#  'c7@0.5': 510,
#  'b6@1.5': 511,
#  'c4@1.25': 512,
#  'd5@1/3': 513,
#  'e3@11/3': 514,
#  '7.11@2.25': 515,
#  '0.4.7@1.5': 516,
#  '2@0.75': 517,
#  'g6@0.25': 518,
#  '9.2@1.0': 519,
#  'd5@0.75': 520,
#  '8@0.25': 521,
#  '0.4@0.5': 522,
#  'r@1.0': 523,
#  '9@3.25': 524,
#  '7.0@1.0': 525,
#  '1.7@0.5': 526,
#  'a3@0.0': 527,
#  '2.3@1/3': 528,
#  '5.9@0.25': 529,
#  'a5@1.5': 530,
#  'f#3@1.0': 531,
#  'r@2.25': 532,
#  'c3@3.0': 533,
#  '0.4@1.0': 534,
#  'b6@0.5': 535,
#  'a3@2.75': 536,
#  '0.3.7@0.25': 537,
#  'c5@1.25': 538,
#  '4.8.11@1.0': 539,
#  'a4@2.75': 540,
#  '2.4.7@0.75': 541,
#  'g3@1.25': 542,
#  '2.3.4.5.6.7@1/3': 543,
#  'g3@2/3': 544,
#  'b1@0.5': 545,
#  '2.4.8@0.25': 546,
#  '11.4@0.75': 547,
#  '7.11.2@3.0': 548,
#  'a5@1/3': 549,
#  'c3@2.75': 550,
#  'e-5@0.25': 551,
#  'r@3.0': 552,
#  '120@tempo': 553,
#  '11.2@1.0': 554,
#  '4.7.10@1.5': 555,
#  'a4@4.0': 556,
#  '11.4@1/6': 557,
#  'e2@1/3': 558,
#  '11.0.4.7@0.5': 559,
#  'b5@2.0': 560,
#  '1.4@0.5': 561,
#  '7.10@1/3': 562,
#  'a3@0.5': 563,
#  'f#4@1.5': 564,
#  '8.0.3@0.5': 565,
#  'e5@11/3': 566,
#  'f#5@0.25': 567,
#  '7.9.1@1.0': 568,
#  'a2@4.0': 569,
#  'e-4@0.25': 570,
#  'a-4@1/3': 571,
#  '5.8.0@1.5': 572,
#  '7@1.25': 573,
#  'e5@0.75': 574,
#  'd4@1/3': 575,
#  '7@1.5': 576,
#  'c#5@0.75': 577,
#  'd6@0.5': 578,
#  '7@1/6': 579,
#  '5.9@0.5': 580,
#  '9.0.2@2/3': 581,
#  'g#3@1.5': 582,
#  'g3@5/12': 583,
#  'b3@2.5': 584,
#  '170@tempo': 585,
#  'r@13/6': 586,
#  '2.7@0.75': 587,
#  '9.0.4@1.25': 588,
#  '4@1.25': 589,
#  '5.7.11@1.0': 590,
#  'g5@0.75': 591,
#  'c#5@0.5': 592,
#  'g#3@0.25': 593,
#  '4.7@2.0': 594,
#  '7.10.2@1.5': 595,
#  'd4@2.0': 596,
#  'e3@1/3': 597,
#  'c2@0.25': 598,
#  '2.5@1.0': 599,
#  '4.7.11@1.0': 600,
#  '2.4.9@1.0': 601,
#  'd2@2.0': 602,
#  'c4@2.0': 603,
#  '<end>': 604,
#  'r@0.25': 605,
#  '9.11.2@1.5': 606,
#  'f#4@1.0': 607,
#  '5.8@1.0': 608,
#  'a4@1/3': 609,
#  '9@0.75': 610,
#  '8.11@0.5': 611,
#  '0.3.7@0.5': 612,
#  '7.10.2@0.25': 613,
#  '8.11@3.75': 614,
#  'b-4@0.75': 615,
#  '9.0.4@1.75': 616,
#  'c1@2.0': 617,
#  '11.2.5.7@0.25': 618,
#  'e-6@0.25': 619,
#  '6.9.0@1.0': 620,
#  '6.11@0.25': 621,
#  '3.7.10@1.0': 622,
#  'b2@1.0': 623,
#  '11.4@1.5': 624,
#  '3.5.10@2.75': 625,
#  'e6@2.0': 626,
#  'b-2@0.5': 627,
#  'f4@1.75': 628,
#  '5.9.0@1.0': 629,
#  '9@0.5': 630,
#  '2.7@3.75': 631,
#  '10.2@0.25': 632,
#  'c6@1.0': 633,
#  'c5@1/3': 634,
#  'g3@3.0': 635,
#  'b4@1.5': 636,
#  '0@1/3': 637,
#  '0@0.25': 638,
#  '2.6.9@0.25': 639,
#  '2.6.9@0.5': 640,
#  '7.11.2@0.5': 641,
#  'g1@1/3': 642,
#  'f5@1.75': 643,
#  'b5@0.25': 644,
#  'r@1.75': 645,
#  'g2@0.5': 646,
#  '4.7.11@2.0': 647,
#  'f3@0.5': 648,
#  '9.0@2.75': 649,
#  'g5@2.0': 650,
#  'c4@0.25': 651,
#  'f#4@0.25': 652,
#  'e5@5/3': 653,
#  'a6@1/3': 654,
#  'a6@1.0': 655,
#  '4.8@0.75': 656,
#  '2.5.9@2.0': 657,
#  '9.2@0.75': 658,
#  'e4@1/3': 659,
#  'b2@1.25': 660,
#  'e6@0.25': 661,
#  'b2@0.5': 662,
#  '1.5@2.0': 663,
#  '11.4@2/3': 664,
#  'e4@1/6': 665,
#  '8.11.2@1.0': 666,
#  '2.8@0.25': 667,
#  '11.2.5.7@2.0': 668,
#  'g#6@1/3': 669,
#  '85@tempo': 670,
#  'd4@1.0': 671,
#  '110@tempo': 672,
#  '100.5@tempo': 673,
#  'e3@5/6': 674,
#  '4.9@1.0': 675,
#  '3/8@time': 676,
#  'e4@3.0': 677,
#  '4.7.10@0.25': 678,
#  '4.5@0.5': 679,
#  '1.4.7@1.0': 680,
#  '4.9@0.5': 681,
#  '6.9@0.75': 682,
#  'e5@0.0': 683,
#  '11.1@0.25': 684,
#  '5.7.11@0.5': 685,
#  '57@tempo': 686,
#  'e3@0.25': 687,
#  '2.4.7@2.0': 688,
#  '7.11.2@1/3': 689,
#  'b2@0.25': 690,
#  '1.5@1.0': 691,
#  '8@0.5': 692,
#  'b5@3.0': 693,
#  '0.6@25/12': 694,
#  'g#3@1.0': 695,
#  '5@1.5': 696,
#  '7.11@0.75': 697,
#  '4.5.7@0.75': 698,
#  'g3@1.5': 699,
#  'b-4@0.25': 700,
#  '9.2@0.5': 701,
#  'a1@1/3': 702,
#  '1.5.8@0.75': 703,
#  'b-3@2.0': 704,
#  '9.0@1/3': 705,
#  'b4@0.75': 706,
#  '0@2.25': 707,
#  'e6@0.75': 708,
#  'c#5@1/3': 709,
#  'c#4@0.25': 710,
#  'f2@1/12': 711,
#  '9.0.4@4.0': 712,
#  '1.5@0.25': 713,
#  'e7@0.25': 714,
#  'f6@0.5': 715,
#  'c3@0.25': 716,
#  '156@tempo': 717,
#  '4.10@0.25': 718,
#  'c4@0.0': 719,
#  'e5@0.25': 720,
#  '5.10@1/3': 721,
#  'b-4@0.5': 722,
#  'b-5@0.25': 723,
#  '2.7@0.25': 724,
#  '0@2.0': 725,
#  '8.9.10.11.0.1@1/3': 726,
#  '4.6.10.0@0.25': 727,
#  '4.8.10@0.5': 728,
#  '9.0@1.0': 729,
#  '11.4@3.75': 730,
#  'c#6@1/3': 731,
#  'a2@2.75': 732,
#  'g#4@0.5': 733,
#  'c#6@0.5': 734,
#  'b1@0.25': 735,
#  'a-4@0.25': 736,
#  '7.10.1@1.0': 737,
#  '9.0.4@0.75': 738,
#  'g#5@0.25': 739,
#  '11.2@0.5': 740,
#  '11.2.4@1/3': 741,
#  'd2@0.25': 742,
#  '5.7@1/3': 743,
#  '5.9.0@2.0': 744,
#  '4.7.9@0.75': 745,
#  '6.9.0@1.5': 746,
#  'e5@4.0': 747,
#  'g5@0.5': 748,
#  '96@tempo': 749,
#  '4.7.10@1.0': 750,
#  'f4@0.75': 751,
#  'f#5@0.5': 752,
#  '1.2@0.25': 753,
#  '240@tempo': 754,
#  'b4@1.0': 755,
#  '4/4@time': 756,
#  'e1@0.5': 757,
#  '0.4.7@1.25': 758,
#  '4.8@1.0': 759,
#  '4.5.7@1.0': 760,
#  'g3@1/6': 761,
#  'c7@1/3': 762,
#  '160@tempo': 763,
#  'b5@4.0': 764,
#  '4.8@0.25': 765,
#  'c5@1.75': 766,
#  'f5@1/3': 767,
#  '0.4.7@2/3': 768,
#  '9.0.4@1.0': 769,
#  'a2@0.5': 770,
#  'b2@0.75': 771,
#  '11.0@3.75': 772,
#  '8.0.3@2.0': 773,
#  'b3@0.25': 774,
#  '11.4@2.0': 775,
#  '0.2.7@5/6': 776,
#  '4.8.11@3.0': 777,
#  'a5@0.5': 778,
#  'f4@1.5': 779,
#  '114@tempo': 780,
#  '10@1.0': 781,
#  '9.0.2@4.0': 782,
#  '6.9@1.0': 783,
#  '7@2.0': 784,
#  'd2@0.5': 785,
#  'b3@0.5': 786,
#  '2@0.5': 787,
#  'd2@1.0': 788,
#  '2.4@0.25': 789,
#  'a3@1.5': 790,
#  '2@3.0': 791,
#  'd4@0.5': 792,
#  '1@1.5': 793,
#  'a5@0.25': 794,
#  'd4@0.25': 795,
#  'c#2@0.25': 796,
#  '2@3.75': 797,
#  'c4@1.5': 798,
#  '8.11.2.4@0.5': 799,
#  '0.5@0.75': 800,
#  '4.5.9.0@1.0': 801,
#  'e7@1/3': 802,
#  '59@tempo': 803,
#  'a-2@0.25': 804,
#  '4.9@0.25': 805,
#  'g3@0.5': 806,
#  '0@1.0': 807,
#  '2.4.8@0.75': 808,
#  'c3@0.5': 809,
#  '50@tempo': 810,
#  '9.11@1.0': 811,
#  'g3@0.25': 812,
#  'a3@1.25': 813,
#  '7.11.2@0.25': 814,
#  '9@1.5': 815,
#  '4.8.11@1/3': 816,
#  '5.9.0@0.25': 817,
#  'g1@1.0': 818,
#  'r@1/12': 819,
#  '4.7@29/12': 820,
#  'r@17/12': 821,
#  '0@1/6': 822,
#  'e5@0.5': 823,
#  'a3@1.75': 824,
#  'd5@1.75': 825,
#  '5.9@1.0': 826,
#  '4.9@3.0': 827,
#  'd7@0.25': 828,
#  'f3@0.75': 829,
#  '8.0@1.0': 830,
#  'f4@0.25': 831,
#  '9.10@0.25': 832,
#  'r@1.5': 833,
#  '7@1/3': 834,
#  '2.7@0.5': 835,
#  '0.6@0.25': 836,
#  'd5@0.5': 837,
#  '10.3@0.5': 838,
#  'e1@0.25': 839,
#  '5.7.0@0.75': 840,
#  '4.7.9@1.0': 841,
#  'e5@1.0': 842,
#  '11@2.25': 843,
#  'f2@1/3': 844,
#  '4@3.75': 845,
#  'g1@0.5': 846,
#  '4.8.11@0.5': 847,
#  '8.11.2.4@0.25': 848,
#  'd4@0.75': 849,
#  'a-5@0.25': 850,
#  '9.2@1.5': 851,
#  'f4@0.5': 852,
#  'g#5@1/3': 853,
#  'e-4@0.5': 854,
#  'b3@1.5': 855,
#  'c5@2/3': 856,
#  '10.0@0.25': 857,
#  '0@0.75': 858,
#  'g2@2/3': 859,
#  'c5@0.25': 860,
#  '9.1@0.25': 861,
#  '4.9@2.0': 862,
#  'r@2.75': 863,
#  '7.10.1.3@0.5': 864,
#  '4.8.11@0.25': 865,
#  'e4@2.0': 866,
#  '0@1.25': 867,
#  '4.5.9.0@2.75': 868,
#  'g4@1.75': 869,
#  'a-4@0.5': 870,
#  '3@1.0': 871,
#  'e4@0.0': 872,
#  '11.2.5.7@0.75': 873,
#  '9.2.3@0.5': 874,
#  '7.0@1/3': 875,
#  'a2@1.0': 876,
#  'c5@2.0': 877,
#  '4.7.9.0@1.5': 878,
#  'b1@1.0': 879,
#  '0.4.7@2.0': 880,
#  'g4@2.75': 881,
#  'r@2/3': 882,
#  '2.5.7@1.0': 883,
#  'g1@0.75': 884,
#  '4.8.11@2.0': 885,
#  'd3@0.5': 886,
#  '150@tempo': 887,
#  'r@13/12': 888,
#  '9.0.2.5@1.0': 889,
#  'c1@0.75': 890,
#  '7.0@0.75': 891,
#  '11.0@0.25': 892,
#  '5.9.0@0.5': 893,
#  'c7@1.75': 894,
#  'e7@1.5': 895,
#  '30@tempo': 896,
#  'b4@0.25': 897,
#  'f3@0.25': 898,
#  '5@1/3': 899,
#  '4@1.5': 900,
#  '0.4.7@0.5': 901,
#  '4.7@1.5': 902,
#  '5.7@0.25': 903,
#  'f#4@2.25': 904,
#  'r@4/3': 905,
#  '0.3.6.9@1.0': 906,
#  '5.8.11.1@0.5': 907,
#  'e5@2.25': 908,
#  'a2@0.25': 909,
#  'g2@1.5': 910,
#  'c6@1/3': 911,
#  'a3@0.25': 912,
#  'c4@0.5': 913,
#  'e4@2.75': 914,
#  'r@3.5': 915,
#  'b5@1/3': 916,
#  '5.8.0@0.25': 917,
#  '4.6.9.11@2.75': 918,
#  '9.1.4@1.0': 919,
#  '11.4@0.5': 920,
#  '2.3.4.5.6.7@0.25': 921,
#  'b6@0.25': 922,
#  'e-1@1.0': 923}

# %%
# dump(tokenizer, open('tokenizer.pkl', 'wb'))

# %% [markdown]
# ## **Image Preprocessing**

# %% [markdown]
# ### **Function Definitions**

# %% [markdown]
# Function to extract image features

# %%
def extract_Image_features(directory, modelName = current_ImgModel):
  #check for the model needed and initialize the model and image size
  if modelName == label_VGG16:
    model = VGG16()
    imgSize = (224, 224)
  else:
    model = InceptionV3(weights='imagenet')
    imgSize = (299, 299)

  #remove the last layer of the model to obtain the features
  #VGG16 has 4096 and InceptionV3 has 2048
  model = Model(inputs=model.inputs, outputs=model.layers[-2].output)

  #print model summary
  print(model.summary())

  #intialize dictionary to extract features
  features = dict()

  #loop over each image in directory
  for imgName in listdir(directory):
    #get image path
    path = directory + '/' + imgName
    #load image and resize
    image = load_img(path, target_size=imgSize)
    #convert image to numpy array
    image = img_to_array(image)
    #reshape image to suit model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    #preprocess image for the model
    image = preprocess_input(image)
    #extract features
    feature = model.predict(image, verbose=0)
    #get image id
    image_id = imgName.split('.')[0]
    #append to dictionary
    features[image_id] = feature

    #print image name
    print("Features extracted for " + imgName)

  return features

# %% [markdown]
# Function to load photo features from pickle file

# %%
def load_featuresPickle(path):
  #load all features
  features = load(open(path, 'rb'))
  return features

# %% [markdown]
# ### Image Preprocessing Steps

# %%
# features = extract_Image_features('image')

# %% [markdown]
# Dump feature to pickle file

# %%
# #print length of features
# print("Extracted features : %d" % len(features))
# # save to pickle file
# dump(features, open('features.pkl', 'wb'))

# %% [markdown]
# # **Model Creation, Training and related Functions**

# %% [markdown]
# ## **Function Definitions**

# %% [markdown]
# Function to create a deep learning model

# %%
from keras.layers import Input, Dropout, Dense, Embedding, Add, MultiHeadAttention, LayerNormalization, GlobalAveragePooling1D
from keras.models import Model
from keras.optimizers import Adam

def create_model_with_transformer(vocab_size, max_length, feature_extractor_label="VG16"):
    # Image feature extractor model
    if feature_extractor_label == "VG16":
        inputs1 = Input(shape=(4096,))
    elif feature_extractor_label == "InceptionV3":
        inputs1 = Input(shape=(2048,))

    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # Sequence model with Transformer
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.2)(se1)

    attention_output = MultiHeadAttention(num_heads=4, key_dim=256)(se2, se2)
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output)
    attention_output = Dropout(0.2)(attention_output)

    attention_output = MultiHeadAttention(num_heads=4, key_dim=256)(attention_output, attention_output)
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output)
    attention_output = Dropout(0.2)(attention_output)

    se3 = GlobalAveragePooling1D()(attention_output)

    # Decoder model
    decoder1 = Add()([fe2, se3])
    decoder2 = Dense(128, activation='relu')(decoder1)
    decoder3 = Dense(256, activation='relu')(decoder2)
    outputs = Dense(vocab_size, activation='softmax')(decoder3)

    # Merging model
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001))

    # Print model summary
    model.summary()

    return model

# Example usage

# %%
from functools import partial
import tensorflow as tf
def create_Model(vocabSize, maxLength):
  #image feature extractor model
  if current_ImgModel == label_VGG16:
    inputs1 = Input(shape = (4096, ))
  elif current_ImgModel == label_InceptionV3:
    inputs1 = Input(shape = (2048, ))

  fe1 = Dropout(0.5)(inputs1)
  fe2 = Dense(256, activation='relu')(fe1)

  #midi sequence model
  inputs2 = Input(shape=(maxLength,))
  #Embedding layer
  se1 = Embedding(vocabSize, 256, mask_zero=True)(inputs2)
  se2 = Dropout(0.2)(se1)
  se3 = LSTM(128, return_sequences=True)(se2)
  se3 = LSTM(256, return_sequences=True)(se3)
  se4 = Dropout(0.2)(se3)
  se5 = LSTM(256)(se4)

  #decoder model
  decoder1 = add([fe2, se5])
  decoder2 = Dense(128, activation='relu')(decoder1)
  decoder2 = Dense(256, activation='relu')(decoder2)
  outputs = Dense(vocabSize, activation='softmax')(decoder2)

  #Merger model
  model = Model(inputs=[inputs1, inputs2], outputs=outputs)
  #compile model
  model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.000001))
  #print model summary
  print("Model Summary")
  model.summary()
  # plot_model(model, to_file='model.png', show_shapes=True)
  return model

# %% [markdown]
# Function to generate input sequences

# %%
def create_sequences(tokenizer, max_length, midi_list, photo, vocab_size):
  #initialize input lists
  X1, X2, y = list(), list(), list()
  #loop through each midi song for the image
  for midi in midi_list:
    #encode the midi sequence
    seq = tokenizer.texts_to_sequences([midi])[0]
    #generate multiple X,y pairs from one midi file
    for i in range(1, len(seq)):
      #generate input and output pair
      in_seq, out_seq = seq[:i], seq[i]
      #pad input sequence
      in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
      #encode output Sequence
      out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
      #append to input lists
      X1.append(photo)
      X2.append(in_seq)
      y.append(out_seq)

  return array(X1), array(X2), array(y)

# %% [markdown]
# Function to generate data for progressive loading

# %%
def data_generator(midiData, photos, tokenizer, max_length, vocab_size):
  #loop forever
  while True:
    for key, midi_list in midiData.items():
      #get photo features
      photo = photos[key][0]
      in_img, in_seq, out_word = create_sequences(tokenizer, max_length, midi_list, photo, vocab_size)
      # yield [in_img, in_seq], out_word
      # print("in_img = ",in_img)
      # print("in_seq = ",in_seq)
      # print("out_word = ",out_word)
      yield (in_img, in_seq), out_word

# %% [markdown]
# Function to map output integer to midi vocabulary

# %%
def get_midiString_for_Integer(integer, tokenizer):
  #loop through tokenizer to find a match
  for midiString, index in tokenizer.word_index.items():
    if index == integer:
      return midiString
  return None

# %% [markdown]
# Function to generate midi string for image

# %%
tokenizer.texts_to_sequences(['<start> 85@tempo 4/4@time G4@2.75 0.4.7@2.75','<start>'])
# Out:
# [[240, 670, 756, 881, 81], [240]]

# %%
def generate_midiSequence(model, tokenizer, photo, maxLength):
  #create initial token
  midiSequence = '<start>' #string with midi events including <start> and <end> tokens
  prediction_list = [] #list with midi events without <start> and <end> tokens

  #iterate over max length of a sequence
  for i in range(maxLength):
    #encode sequence
    sequence =  tokenizer.texts_to_sequences([midiSequence])[0]
    #pad sequence
    sequence = pad_sequences([sequence], maxlen=maxLength)
    #predict next midi event string
    yhat = model.predict([photo,sequence], verbose=0)
    #print(yhat)
    #obtain event with highest probability
    #import numpy as np
    #yhat2 = np.argsort(np.max(yhat, axis=0))[-2]
    yhat = argmax(yhat)
    #map integer to midi string
    midiString = get_midiString_for_Integer(yhat, tokenizer)
    #stop if cannot find
    if midiString is None:
      break
    #append midiString to sequence
    if not midiString == '<start>':
        midiSequence += ' ' + midiString
    #stop if end of midi
    if midiString == '<end>':
      break
    #append midi event string to prediction list
    if not midiString == '<start>':
        prediction_list.append(midiString)

  return midiSequence, prediction_list

# %% [markdown]
# Function to create a midi from prediction list

# %%
def create_midi(prediction_output, midiName):
  #initiate offset to 0
  offset = 0.0
  #initiate midi stram
  midi_stream = stream.Stream()

  #loop over each midiString patter in prediction Output
  for pattern in prediction_output:
    #Seperate midiString into event and time by @ symbol
    patternString = pattern.split('@')[0] #0 position stores midi event
    if pattern.split('@')[1] == 'tempo':
      #if event is a tempo, append to midiStream and continue to next iteration
      tp0 = tempo.MetronomeMark(patternString)
      tp0.setQuarterBPM(int(float(patternString)))
      midi_stream.append(tp0)
      continue
    #check if position 1 == time to check if event is a timeSignature
    if pattern.split('@')[1] == 'time':
      #if event is a timeSignature, append to midiStream and continue to next iteration
      ts0 = meter.TimeSignature(patternString)
      midi_stream.append(ts0)
      continue
    #check if '.' in patterString  or it patternString is a digit to detemine if the event is a chord
    if ('.' in patternString) or patternString.isdigit():
        #if event is a chord, obtain notes
        notes_in_chord = patternString.split('.')
        notes = []
        #loop for each note and create a notes list
        for current_note in notes_in_chord:
          new_note = note.Note(int(current_note))
          new_note.storedInstrument = instrument.Piano()
          notes.append(new_note)
        #create a chord using notes list
        new_chord = chord.Chord(notes)
        #set duration of chord
        new_chord.quarterLength = eval(pattern.split('@')[1])
        #update offset
        new_chord.offset = offset
        offset += new_chord.quarterLength
        #append chord to midi Stream
        midi_stream.append(new_chord)
    # pattern is a note or rest
    else:
      #if pattern is a rest
      if patternString == 'r':
        #create rest event
        new_note = note.Rest()
        #set duration
        new_note.quarterLength = eval(pattern.split('@')[1])
        #update offest
        new_note.offset = offset
        offset += new_note.quarterLength
        #append to midi stream
        midi_stream.append(new_note)
      else:
        #if pattern is a note
        #create note
        new_note = note.Note(patternString)
        #set note duration
        new_note.quarterLength = eval(pattern.split('@')[1])
        #update offset
        new_note.offset = offset
        offset += new_note.quarterLength
        new_note.storedInstrument = instrument.Piano()
        midi_stream.append(new_note)

  midi_stream.makeMeasures(inPlace = True)

  print('Saving Output file as midi....')

  midi_stream.write('midi', fp='testMidi_trans_2/' + midiName + '.mid')

# %% [markdown]
# Function to extract features of image to generate music

# %%
def extract_featuresPredict(path, modelName = current_ImgModel):
  #initialize model and resize image
  if modelName == label_VGG16:
    model = model = VGG16()
    image = load_img(path, target_size=(224, 224))
  elif modelName == label_InceptionV3:
    model = InceptionV3(weights='imagenet')
    # image = load_img(filename, target_size=(299, 299))

  #remove last layer of model
  model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
  #convert image to numpy array
  image = img_to_array(image)
  #reshape array
  image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
  #preprocess image
  image = preprocess_input(image)
  #obtain features
  features = model.predict(image, verbose=0)

  return features

# %% [markdown]
# Model Creation and Training Steps

# %% [markdown]
# Load training photo features

# %%
train_features = load_featuresPickle('features.pkl')
print(len(train_features))
# Out:
# 3000

# %% [markdown]
# Training midi data is already loaded in train_midi dictionary

# %% [markdown]
# Next create the model

# %%
#initialize epochs
epochs = 250
#initials steps to generate data
steps = len(train_midi)
#create model
# model = create_Model(vocabSize= vocabSize, maxLength=maxLength)
model = create_model_with_transformer(vocab_size= vocabSize, max_length=maxLength)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 236)]                0         []
#
#  embedding_1 (Embedding)     (None, 236, 256)             250368    ['input_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 236, 256)             0         ['embedding_1[0][0]']
#
#  multi_head_attention (Mult  (None, 236, 256)             1051904   ['dropout_4[0][0]',
#  iHeadAttention)                                                     'dropout_4[0][0]']
#
#  layer_normalization (Layer  (None, 236, 256)             512       ['multi_head_attention[0][0]']
#  Normalization)
#
#  dropout_5 (Dropout)         (None, 236, 256)             0         ['layer_normalization[0][0]']
#
#  multi_head_attention_1 (Mu  (None, 236, 256)             1051904   ['dropout_5[0][0]',
#  ltiHeadAttention)                                                   'dropout_5[0][0]']
#
#  input_3 (InputLayer)        [(None, 4096)]               0         []
#
#  layer_normalization_1 (Lay  (None, 236, 256)             512       ['multi_head_attention_1[0][0]
#  erNormalization)                                                   ']
#
#  dropout_3 (Dropout)         (None, 4096)                 0         ['input_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 236, 256)             0         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dense_4 (Dense)             (None, 256)                  1048832   ['dropout_3[0][0]']
#
#  global_average_pooling1d (  (None, 256)                  0         ['dropout_6[0][0]']
#  GlobalAveragePooling1D)
#
#  add_1 (Add)                 (None, 256)                  0         ['dense_4[0][0]',
#                                                                      'global_average_pooling1d[0][
#                                                                     0]']
#
#  dense_5 (Dense)             (None, 128)                  32896     ['add_1[0][0]']
#
#  dense_6 (Dense)             (None, 256)                  33024     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 978)                  251346    ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 3721298 (14.20 MB)
# Trainable params: 3721298 (14.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Define path to save best model and initialize Checkpoint

# %%
#save weights
# filepath = 'training/cp.ckpt'
filepath = 'training_new_model/cp.weights.h5'
checkpoint_dir = os.path.dirname(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

# %% [markdown]
# Train model

# %%
print(len(train_features['0001'][0]))
print(train_features['0002'][0])
print(train_features['0003'][0])
print(train_features['0101'][0])
print(train_features['0301'][0])
# Out:
# 4096
# [0.         0.59926796 0.         ... 2.9459355  0.         0.4254136 ]
# [2.0397887  0.         0.72674024 ... 0.6001403  0.         3.0588882 ]
# [0.        3.2399967 0.        ... 0.        1.675365  0.9805833]
# [5.0451164  0.         0.23566201 ... 0.         0.         1.1905509 ]

# %%
# for i in range(epochs):
#   #create data generator
#   generator  = data_generator(train_midi, train_features, tokenizer, maxLength, vocabSize)
#   #fit model for one epoch
#   print("Epoch No : " + str(i + 1))
#   model.fit(generator, epochs=1, steps_per_epoch=steps, callbacks=[checkpoint], verbose=1)

# %%
# #resume training
# #load weights
# filepath = 'training/cp.ckpt'
# checkpoint_dir = os.path.dirname(filepath)
# checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

# %%
# model = create_Model(vocabSize, maxLength)
# model.load_weights(filepath)
# tokenizer = load(open(data_dir + 'tokenizer.pkl', 'rb'))

# %%
# for i in range(epochs):
#   #create data generator
#   generator = data_generator(train_midi, train_features, tokenizer, maxLength, vocabSize)
#   #fit model for one epoch
#   print("Epoch No : " + str(i + 1))
#   model.fit(generator, epochs=1, steps_per_epoch=steps, callbacks=[checkpoint], verbose=1)

# %%
# #resume training
# #load weights
# filepath = data_dir + 'training_2/cp.ckpt'
# checkpoint_dir = os.path.dirname(filepath)
# checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

# %%
# model = create_Model(vocabSize, maxLength)
# model.load_weights(filepath)
# tokenizer = load(open(data_dir + 'tokenizer.pkl', 'rb'))
# Out:
# Model Summary
# Model: "model_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_72 (InputLayer)          [(None, 114)]        0           []
#
#  embedding_20 (Embedding)       (None, 114, 256)     87040       ['input_72[0][0]']
#
#  dropout_61 (Dropout)           (None, 114, 256)     0           ['embedding_20[0][0]']
#
#  input_71 (InputLayer)          [(None, 4096)]       0           []
#
#  lstm_40 (LSTM)                 (None, 114, 128)     197120      ['dropout_61[0][0]']
#
#  dropout_60 (Dropout)           (None, 4096)         0           ['input_71[0][0]']
#
#  dropout_62 (Dropout)           (None, 114, 128)     0           ['lstm_40[0][0]']
#
#  dense_60 (Dense)               (None, 256)          1048832     ['dropout_60[0][0]']
#
#  lstm_41 (LSTM)                 (None, 256)          394240      ['dropout_62[0][0]']
#
#  add_20 (Add)                   (None, 256)          0           ['dense_60[0][0]',
#                                                                   'lstm_41[0][0]']
#
#  dense_61 (Dense)               (None, 256)          65792       ['add_20[0][0]']
#
#  dense_62 (Dense)               (None, 340)          87380       ['dense_61[0][0]']
#
# ==================================================================================================
# Total params: 1,880,404
# Trainable params: 1,880,404
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# for i in range(epochs):
#   #create data generator
#   generator = data_generator(train_midi, train_features, tokenizer, maxLength, vocabSize)
#   #fit model for one epoch
#   print("Epoch No : " + str(i + 1))
#   model.fit(generator, epochs=1, steps_per_epoch=steps, callbacks=[checkpoint], verbose=1)
# Out:
# Epoch No : 1
# 300/300 [==============================] - ETA: 0s - loss: 0.1251
# Epoch 1: loss improved from inf to 0.12512, saving model to E:\uniSlides\CS\Research\FinalDataset\FinalData\unique_2VGG_FINAL\\training_2\cp.ckpt
# 300/300 [==============================] - 958s 3s/step - loss: 0.1251
# Epoch No : 2
# 300/300 [==============================] - ETA: 0s - loss: 0.1025
# Epoch 1: loss improved from 0.12512 to 0.10249, saving model to E:\uniSlides\CS\Research\FinalDataset\FinalData\unique_2VGG_FINAL\\training_2\cp.ckpt
# 300/300 [==============================] - 871s 3s/step - loss: 0.1025
# Epoch No : 3
# 300/300 [==============================] - ETA: 0s - loss: 0.1026
# Epoch 1: loss did not improve from 0.10249
# 300/300 [==============================] - 885s 3s/step - loss: 0.1026
# Epoch No : 4
# 300/300 [==============================] - ETA: 0s - loss: 0.1393
# Epoch 1: loss did not improve from 0.10249
# 300/300 [==============================] - 775s 3s/step - loss: 0.1393
# Epoch No : 5
# 191/300 [==================>...........] - ETA: 4:11 - loss: 0.1141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
#       4 #fit model for one epoch
#       5 print("Epoch No : " + str(i + 1))
# ----> 6 model.fit(generator, epochs=1, steps_per_epoch=steps, callbacks=[checkpoint], verbose=1)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\cpuml\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Generate a melody for a test image

# %%
import tensorflow as tf
#load tokenizer from pickle
tokenizer = load(open('tokenizer.pkl', 'rb'))
#load best model
# model = create_Model(vocabSize, maxLength)
model = create_model_with_transformer(vocab_size= vocabSize, max_length=maxLength)
# filepath = 'training/cp.weights.h5'
filepath = 'training_new_model/trans.weights.h5'
model.load_weights(filepath)
# give the path to testImages, here testImages = image
images = glob('test/image/*.jpg')
print(images)
prv =0
ii = 0
prvtxt = ""
for img in images:
    photo = extract_featuresPredict(img)
    #generate midi
    midiSequence, prediction_output = generate_midiSequence(model, tokenizer, photo, maxLength)
    if(ii > 0) : 
        print(sum((photo - prv)[0]))
        prv = photo
    ii += 1
    print("Midi Sequnce in text")
    print(midiSequence)
    print(prvtxt == midiSequence)
    prvtxt = midiSequence

    #create midi file
    create_midi(prediction_output, img.split('.')[0].rsplit('/')[-1])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 236)]                0         []
#
#  embedding_2 (Embedding)     (None, 236, 256)             250368    ['input_6[0][0]']
#
#  dropout_8 (Dropout)         (None, 236, 256)             0         ['embedding_2[0][0]']
#
#  multi_head_attention_2 (Mu  (None, 236, 256)             1051904   ['dropout_8[0][0]',
#  ltiHeadAttention)                                                   'dropout_8[0][0]']
#
#  layer_normalization_2 (Lay  (None, 236, 256)             512       ['multi_head_attention_2[0][0]
#  erNormalization)                                                   ']
#
#  dropout_9 (Dropout)         (None, 236, 256)             0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  multi_head_attention_3 (Mu  (None, 236, 256)             1051904   ['dropout_9[0][0]',
#  ltiHeadAttention)                                                   'dropout_9[0][0]']
#
#  input_5 (InputLayer)        [(None, 4096)]               0         []
#
#  layer_normalization_3 (Lay  (None, 236, 256)             512       ['multi_head_attention_3[0][0]
#  erNormalization)                                                   ']
#
#  dropout_7 (Dropout)         (None, 4096)                 0         ['input_5[0][0]']
#
#  dropout_10 (Dropout)        (None, 236, 256)             0         ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dense_8 (Dense)             (None, 256)                  1048832   ['dropout_7[0][0]']
#
#  global_average_pooling1d_1  (None, 256)                  0         ['dropout_10[0][0]']
#   (GlobalAveragePooling1D)
#
#  add_2 (Add)                 (None, 256)                  0         ['dense_8[0][0]',
#                                                                      'global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 128)                  32896     ['add_2[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  33024     ['dense_9[0][0]']
#
#  dense_11 (Dense)            (None, 978)                  251346    ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 3721298 (14.20 MB)
# Trainable params: 3721298 (14.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 59 variables.
# ['test/image/0561.jpg', 'test/image/0230.jpg', 'test/image/0940.jpg', 'test/image/0700.jpg', 'test/image/0911.jpg', 'test/image/0410.jpg', 'test/image/0356.jpg', 'test/image/0270.jpg', 'test/image/1010.jpg', 'test/image/0722.jpg', 'test/image/0685.jpg', 'test/image/0184.jpg', 'test/image/0050.jpg', 'test/image/0883.jpg', 'test/image/0824.jpg', 'test/image/0183.jpg', 'test/image/0386.jpg', 'test/image/0582.jpg', 'test/image/0299.jpg', 'test/image/0723.jpg', 'test/image/0884.jpg', 'test/image/0825.jpg', 'test/image/0069.jpg', 'test/image/0968.jpg', 'test/image/0932.jpg', 'test/image/0139.jpg', 'test/image/0398.jpg', 'test/image/0394.jpg', 'test/image/0762.jpg', 'test/image/0090.jpg', 'test/image/1018.jpg', 'test/image/0278.jpg', 'test/image/0780.jpg', 'test/image/0711.jpg', 'test/image/0060.jpg', 'test/image/0683.jpg', 'test/image/0074.jpg', 'test/image/0744.jpg', 'test/image/0466.jpg', 'test/image/0180.jpg', 'test/image/0415.jpg', 'test/image/0646.jpg', 'test/image/0255.jpg', 'test/image/0263.jpg', 'test/image/0925.jpg', 'test/image/0297.jpg', 'test/image/0604.jpg', 'test/image/0948.jpg', 'test/image/0141.jpg', 'test/image/0833.jpg', 'test/image/0254.jpg', 'test/image/0614.jpg', 'test/image/0800.jpg', 'test/image/0236.jpg', 'test/image/0012.jpg', 'test/image/0205.jpg', 'test/image/0031.jpg', 'test/image/0463.jpg', 'test/image/0551.jpg', 'test/image/0978.jpg', 'test/image/0775.jpg', 'test/image/0678.jpg', 'test/image/0199.jpg', 'test/image/0781.jpg', 'test/image/0220.jpg', 'test/image/0331.jpg', 'test/image/0754.jpg', 'test/image/0253.jpg', 'test/image/0817.jpg', 'test/image/0490.jpg', 'test/image/0215.jpg', 'test/image/0300.jpg', 'test/image/0248.jpg', 'test/image/0349.jpg', 'test/image/0382.jpg', 'test/image/0988.jpg', 'test/image/0173.jpg', 'test/image/0721.jpg', 'test/image/0313.jpg', 'test/image/0044.jpg', 'test/image/0662.jpg', 'test/image/0401.jpg', 'test/image/0309.jpg', 'test/image/0312.jpg', 'test/image/0571.jpg', 'test/image/0765.jpg', 'test/image/0638.jpg', 'test/image/0468.jpg', 'test/image/0628.jpg', 'test/image/0724.jpg', 'test/image/0595.jpg', 'test/image/0567.jpg', 'test/image/0087.jpg', 'test/image/0456.jpg', 'test/image/0453.jpg', 'test/image/0122.jpg', 'test/image/0330.jpg', 'test/image/0350.jpg', 'test/image/0172.jpg', 'test/image/0472.jpg', 'test/image/0112.jpg', 'test/image/0771.jpg', 'test/image/0058.jpg', 'test/image/0815.jpg', 'test/image/0562.jpg', 'test/image/0320.jpg', 'test/image/0178.jpg', 'test/image/0011.jpg', 'test/image/0116.jpg', 'test/image/0197.jpg', 'test/image/0956.jpg', 'test/image/0761.jpg', 'test/image/0479.jpg', 'test/image/0796.jpg', 'test/image/0801.jpg', 'test/image/0536.jpg', 'test/image/0053.jpg', 'test/image/0907.jpg', 'test/image/0238.jpg', 'test/image/0192.jpg', 'test/image/0677.jpg', 'test/image/0709.jpg', 'test/image/0818.jpg', 'test/image/1014.jpg', 'test/image/0726.jpg', 'test/image/0990.jpg', 'test/image/0701.jpg', 'test/image/0201.jpg', 'test/image/0224.jpg', 'test/image/0805.jpg', 'test/image/0966.jpg', 'test/image/0340.jpg', 'test/image/0590.jpg', 'test/image/0504.jpg', 'test/image/1008.jpg', 'test/image/0671.jpg', 'test/image/0420.jpg', 'test/image/0493.jpg', 'test/image/0913.jpg', 'test/image/0156.jpg', 'test/image/0857.jpg', 'test/image/0406.jpg', 'test/image/0539.jpg', 'test/image/0511.jpg', 'test/image/0641.jpg', 'test/image/0727.jpg', 'test/image/0450.jpg', 'test/image/0621.jpg', 'test/image/0778.jpg', 'test/image/0170.jpg', 'test/image/0003.jpg', 'test/image/0812.jpg', 'test/image/1005.jpg', 'test/image/0922.jpg', 'test/image/0888.jpg', 'test/image/0649.jpg', 'test/image/0768.jpg', 'test/image/0373.jpg', 'test/image/0634.jpg', 'test/image/0443.jpg', 'test/image/0344.jpg', 'test/image/0954.jpg', 'test/image/0158.jpg', 'test/image/0008.jpg', 'test/image/0661.jpg', 'test/image/0602.jpg', 'test/image/0642.jpg', 'test/image/0009.jpg', 'test/image/0986.jpg', 'test/image/0322.jpg', 'test/image/0889.jpg', 'test/image/0732.jpg', 'test/image/0433.jpg', 'test/image/0520.jpg ...
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 1970.6730742193758
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 728.4086403213441
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -680.8007490634918
# Midi Sequnce in text
# <start> 4/4@time r@3.0 7@1/3 b2@0.5 d3@1/3 r@0.25 g3@0.5 d3@1/3 r@0.25 b2@0.5 0@1/3 r@3.0 r@0.25 e2@0.5 g2@0.25 r@0.25 a2@0.5 g2@1/3 r@0.25 e2@0.5 0@1/3 r@2.75 r@0.25 e2@0.5 g2@1/3 r@0.25 a2@0.5 g2@0.25 g2@0.75 e4@0.25 0@1/3 r@0.25 e2@0.5 g2@1/3 r@0.25 r@0.25 g4@0.5 a2@0.5 g4@1.0 g2@1/3 r@0.25 e2@0.5 c5@0.25 0@0.25 c5@0.75 r@0.25 e2@0.5 g4@1.0 g2@1/3 r@0.25 a2@0.5 e4@0.5 g2@0.5 r@0.75 r@1.75 <end>
# False
# Saving Output file as midi....
# 67.97134155035019
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 647.9790366441011
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -577.166384100914
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 705.7113161832094
# Midi Sequnce in text
# <start> 4/4@time g4@1.0 g3@2.0 c4@1.0 d4@1.0 b1@0.5 b2@0.5 d4@3.0 d3@0.5 f3@0.5 a3@1.0 e2@0.5 b2@0.5 d4@0.75 d3@0.5 g#3@0.5 r@0.25 e4@1.0 b3@1.0 9.0@1.0 4.9@1.0 a3@2.0 4.9@2.0 9.0.4@1.0 4.7@1.0 9.0@1.0 4.7@2.0 g4@1.0 9.0.4@1.0 4.6@1.0 4.9@2.0 4.6@1.0 9.2.3@0.5 4.6@1.0 r@0.5 3.5@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -635.7887207567692
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -345.93202693760395
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 188.74368308484554
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 237.42345141619444
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -447.9995003566146
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# 302.5696579962969
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 189.43228889256716
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -380.55202993378043
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -27.833930864930153
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 93.47275164723396
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -86.14862793311477
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# 609.3595361970365
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -451.702062740922
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# True
# Saving Output file as midi....
# -89.40489712357521
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# True
# Saving Output file as midi....
# -414.5151876062155
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# False
# Saving Output file as midi....
# 650.4437925070524
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# True
# Saving Output file as midi....
# 52.878214329481125
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -295.1727788671851
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# 24.26201432943344
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 473.50559674203396
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -656.7962800189853
# Midi Sequnce in text
# <start> 4/4@time g4@1.0 g3@2.0 c4@1.0 d4@1.0 b1@0.5 b2@0.5 d4@3.0 d3@0.5 f3@0.5 a3@1.0 e2@0.5 b2@0.5 d4@0.75 d3@0.5 g#3@0.5 r@0.25 e4@1.0 b3@1.0 9.0@1.0 4.9@1.0 a3@2.0 4.9@2.0 9.0.4@1.0 4.7@1.0 9.0@1.0 4.7@2.0 g4@1.0 9.0.4@1.0 4.6@1.0 4.9@2.0 4.6@1.0 9.2.3@0.5 4.6@1.0 r@0.5 3.5@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -2.904041014611721
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -83.98942506313324
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 270.1841493397951
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 0.0
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 98.66101463139057
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 78.09513586014509
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -476.18568563461304
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 289.58462865650654
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 9.844902500510216
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 98.66101463139057
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 474.86386969685555
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -573.5248866230249
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 0.0
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -350.38076278567314
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 261.8286410346627
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -347.80580807477236
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 402.57358641922474
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 132.4453600347042
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -153.88882271200418
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 926.2810595929623
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -826.1800577044487
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -110.51201627776027
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# True
# Saving Output file as midi....
# 65.63882113620639
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 301.62999123334885
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 57.516570284962654
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -387.586674913764
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 217.65143802762032
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -452.8222359716892
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# False
# Saving Output file as midi....
# 891.4988810867071
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -627.5053640156984
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -244.90542063117027
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 88.7763783633709
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 221.17254920303822
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -22.560420736670494
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 120.81942564249039
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -616.364179879427
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 667.6623723655939
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -222.79645620286465
# Midi Sequnce in text
# <start> 4/4@time b4@1.0 c#4@3.75 a2@3.75 a4@0.5 e4@1.0 d4@1.5 r@0.25 r@0.25 9@3.75 r@0.25 f#4@1.0 r@0.25 g4@1.0 b3@2.5 11.4@3.75 f#4@0.5 d4@1.0 b3@1.5 r@1.5 r@0.25 e3@2.0 9.2@3.75 d3@2.0 r@0.25 11.0.4@1.0 11.0@3.75 a4@0.5 e4@1.0 d4@1.5 r@0.25 <end>
# False
# Saving Output file as midi....
# 372.22329615056515
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -374.25505343079567
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 266.35789999365807
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 14.745668940246105
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -38.16185510903597
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# False
# Saving Output file as midi....
# 282.15809202194214
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# True
# Saving Output file as midi....
# -57.05354082584381
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -792.1519968509674
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -129.1526260599494
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 1007.3290656581521
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# 49.06192860007286
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -336.7747368514538
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# True
# Saving Output file as midi....
# -284.95311015844345
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -5.344228282570839
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 105.29318788647652
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 279.40068289637566
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -350.9095270037651
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -33.78434099256992
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 604.8949058651924
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -472.4495498687029
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -293.7047081589699
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -238.2169184088707
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 308.11931301653385
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 315.8169566988945
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -462.2021397948265
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# True
# Saving Output file as midi....
# 983.923647031188
# Midi Sequnce in text
# <start> 4/4@time 0.4.7@2.0 9.0.4@4.0 f5@2.0 0.5@2.0 9.0.2@4.0 d5@2.0 7.0@2.0 4.7@4.0 f5@1.0 e5@1.0 2.5.9@2.0 9.0.2@4.0 e4@2.0 a4@0.5 a2@4.0 c5@0.5 g5@1.0 f5@1.0 e5@1.0 2.4.7@2.0 c3@2.0 d4@2.0 d3@2.0 <end>
# False
# Saving Output file as midi....
# -778.0359885394573
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -117.65186435356736
# Midi Sequnce in text
# <start> 4/4@time g4@1.0 g3@2.0 c4@1.0 d4@1.0 b1@0.5 b2@0.5 d4@3.0 d3@0.5 f3@0.5 a3@1.0 e2@0.5 b2@0.5 d4@0.75 d3@0.5 g#3@0.5 r@0.25 e4@1.0 b3@1.0 9.0@1.0 4.9@1.0 a3@2.0 4.9@2.0 9.0.4@1.0 4.7@1.0 9.0@1.0 4.7@2.0 g4@1.0 9.0.4@1.0 4.6@1.0 4.9@2.0 4.6@1.0 9.2.3@0.5 4.6@1.0 r@0.5 3.5@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 183.29068540036678
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -68.89623962342739
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 918.5483557730913
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -330.51455791294575
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -469.19714553654194
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 462.9012451916933
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# 190.19138915091753
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -604.3720332309604
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -353.5061249360442
# Midi Sequnce in text
# <start> 4/4@time a4@0.25 9.0.4@0.5 r@0.25 b4@1.0 9.0.4@0.5 9.0.4@0.5 a4@2.0 0.3.5@2.0 r@0.5 r@0.5 r@1.5 r@1.5 9.11.4@2.0 4@2.0 4.8.11@0.5 4.8.11@1.5 11.4@1.5 9.0.4@2.5 9@2.5 9.0.4@0.5 9@0.5 <end>
# False
# Saving Output file as midi....
# 947.4267257601023
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -908.3015724569559
# Midi Sequnce in text
# <start> 4/4@time r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 r@3.0 c2@0.5 g2@0.5 e3@1.0 g2@1.0 g4@2.75 c2@0.5 g2@0.5 e3@1.0 c2@0.5 b1@0.5 r@0.25 d5@1.0 a1@0.5 e2@0.5 c5@2.0 c3@0.5 e3@0.5 a3@1.0 b4@1.5 f2@0.5 c3@0.5 a3@2.0 a4@0.5 g4@0.5 f4@0.5 g4@2.0 e2@0.5 c3@0.5 g3@1.5 r@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 530.6331677138805
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# 210.4838972762227
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -268.88411047309637
# Midi Sequnce in text
# <start> 4/4@time e4@3.0 4.7.11@4.0 e4@2.0 r@1.0 g#4@1.0 4.8.11@3.0 g#4@2.0 b4@1.0 4.8.11@2.0 d5@1.5 r@1.0 c#5@0.5 c5@1.0 9.0.4@1.0 c5@3.0 9.0.4@2.0 9.0.4@2.0 c5@2.0 r@1.0 f#5@1.0 2.6.9@3.0 f#5@1.0 d5@1.0 c5@1.0 2.6.9@2.0 d5@1.5 r@1.0 c5@0.5 b4@1.0 4.7.11@1.0 4.7.11@2.0 4.7.11@2.0 r@1.0 e3@1.0 7.11@0.5 r@0.5 7.11@0.5 r@0.5 <end>
# False
# Saving Output file as midi....
# -201.43908970057964
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# False
# Saving Output file as midi....
# -83.51402060687542
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# -5.344228282570839
# Midi Sequnce in text
# <start> 4/4@time r@3.0 r@3.0 r@3.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 b4@0.5 a4@0.5 e6@1.0 a3@0.5 e4@0.5 c6@0.5 a4@0.5 d6@1.0 c5@0.5 b4@0.5 e-6@0.5 a4@0.5 e6@2.0 a3@0.5 e4@0.5 a4@0.5 c5@0.5 a5@1.0 b4@0.5 a4@0.5 f6@0.5 d3@0.5 r@2.5 <end>
# True
# Saving Output file as midi....
# 52.57010914385319
# Midi Sequnce in text
# <start> 4/4@time a4@1.5 4@0.25 r@0.5 d2@0.5 5@2.0 g4@0.25 r@0.75 g4@0.5 g4@0.75 r@0.5 r@0.5 d2@0.25 d2@0.25 f4@1.75 7@2.0 f4@0.25 r@1.0 r@0.5 g2@0.5 e-4@1.75 c3@0.75 c3@1.25 e-4@0.25 e4@1.0 c2@1.0 r@1.0 4@1.75 a4@0.25 a4@1.5 4@0.25 r@0.5 d2@0.5 5@1.5 g4@0.25 r@0.75 g4@0.25 r@0.25 r@1.25 <end>
# False
# Saving Output file as midi....

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Evalution

# %% [markdown]
# Function to calculate average tone span (semitones between lowest and highest note in the melody)

# %%
def getTonespan(testingSongs):
    scale = {"C": 0, "C#": 1, "D-" : 1, "D" : 2, 'D#' : 3, "E-": 3, "E" : 4, "F-": 4, "E#" : 5, "F" : 5, "F#" : 6, "G-" : 6, "G" : 7,
             "G#": 8, "A-": 8, "A": 9, "A#": 10, "B-": 10, "B": 11, "C-":11, "B#": 12 }
    tonespans = []
    for file in testingSongs:
        #print(file)
        try:
            midi = converter.parse(file) #convert to midi
        except:
            print("Error in parsing " + str(file))
            continue
        #tranpose song
        try:
            midi = transpose(midi)
        except:
            print("Error in obtaining key for " + str(file))
            continue
        startBar = getStartingBar(midi)
        midi = midi.measures(startBar, startBar + 7)
        midi = midi.flat
        minNote = {"value": float('inf'), "name": ''}
        minOct = float('inf')
        maxNote = {"value": float('-inf'), "name": ''}
        maxOct = float('-inf')
        for event in midi:
            if isinstance(event, note.Note):
                if(int(str(event.pitch)[-1]) < minOct):
                    minOct = int(str(event.pitch)[-1])
                if(int(str(event.pitch)[-1]) > maxOct):
                    maxOct = int(str(event.pitch)[-1])
        #print("Min : " + str(minOct) + " Max: " + str(maxOct))
        for event in midi:
            if isinstance(event, note.Note):
                if(int(str(event.pitch)[-1]) == minOct):
                    if( scale[str(event.pitch)[:-1]] < minNote["value"]):
                        minNote["value"] = scale[str(event.pitch)[:-1]]
                        minNote["name"] = event
                if(int(str(event.pitch)[-1]) == maxOct):
                    if( scale[str(event.pitch)[:-1]] > maxNote["value"]):
                        maxNote["value"] = scale[str(event.pitch)[:-1]]
                        maxNote["name"] = event
        #print("MinNote: " + str(minNote["value"]) + " name: " + str(minNote["name"].pitch))
        #print("MaxNote: " + str(maxNote["value"]) + " name: " + str(maxNote["name"].pitch))

        semitones = interval.Interval(minNote["name"], maxNote["name"]).semitones
        #print("semitones: " + str(semitones))
        tonespans.append(int(semitones))

    avg = sum(tonespans)/len(tonespans)
    return avg

# %% [markdown]
# Calculate avg tonespan for all midi files in dataset

# %%
# datasetSongs = glob(data_dir + 'midi/*.mid')
datasetSongs = glob('audio/*.mid')
print("Avg tone span in dataset: " + str(getTonespan(datasetSongs)))
# Out:
# Ok
# f# minor Ok
# Ok
# A- major Ok
# Ok
# e minor Ok
# Ok
# E- major Ok
# Ok
# C major Ok
# Ok
# E major Ok
# Ok
# g minor Ok
# Ok
# d minor Ok
# Ok
# b- minor Ok
# Ok
# C major Ok
# Ok
# g minor Ok
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[36], line 3
#       1 # datasetSongs = glob(data_dir + 'midi/*.mid')
#       2 datasetSongs = glob('audio/*.mid')
# ----> 3 print("Avg tone span in dataset: " + str(getTonespan(datasetSongs)))
#
# Cell In[35], line 18, in getTonespan(testingSongs)
#      16     print("Error in obtaining key for " + str(file))
#      17     continue
# ---> 18 startBar = getStartingBar(midi)
#      19 midi = midi.measures(startBar, startBar + 7)
#      20 midi = midi.flat
#
# Cell In[9], line 12, in getStartingBar(score)
#      10         continue
#      11     break;
# ---> 12 return num
#
# UnboundLocalError: local variable 'num' referenced before assignment

# %% [markdown]
# Calculate avg tonespan for a sample of 16 midi files generated from the model

# %%
testingSongs = glob('testMidi/*.mid')
print("Avg tone span in dataset: " + str(getTonespan(testingSongs)))

# %% [markdown]
# Function to calculate the scale consistency of a set of midi files

# %%
def getAvgScaleConsistency(testingSongs):
    A_minor = ["A", "B", "C", "D", 'E', "F", "G#"]
    C_major = ["C", "D", "E", "F", 'G', "A", "B"]

    allRatios = []

    for file in testingSongs:
        try:
            midi = converter.parse(file) #convert to midi
        except:
            print("Error in parsing " + str(file))
            continue
        #tranpose song
        try:
            midi = transpose(midi)
        except:
            print("Error in obtaining key for " + str(file))
            continue

        startBar = getStartingBar(midi)
        midi = midi.measures(startBar, startBar + 7)
        midi = midi.flat

        correctNotes = 0
        FG_list = []
        GF_list = []
        totNotes = 0
        key = midi.analyze("key")
        if key.mode == "major":
            for event in midi:
                if isinstance(event, note.Note):
                    totNotes += 1
                    if (str(event.pitch)[:-1] in C_major):
                                correctNotes += 1
        elif key.mode == "minor":
            for event in midi:
                if isinstance(event, note.Note):
                    totNotes += 1
                    if((str(event.pitch)[:-1] == "F#") & (len(FG_list) == 0)):
                        FG_list.append("F#")
                        continue
                    if(str(event.pitch)[:-1] == "G#"):
                        if(len(FG_list) == 1):
                            if(FG_list[0] == "F#"):
                                correctNotes += 2
                                FG_list = []
                                continue




                    if((str(event.pitch)[:-1] == "G")  & (len(GF_list) == 0)):
                        GF_list.append("G")
                        continue
                    if(str(event.pitch)[:-1] == "F"):
                        if(len(FG_list) == 1):
                            if(FG_list[0] == "G"):
                                correctNotes += 2
                                GF_list = []
                                continue


                    if (str(event.pitch)[:-1] in A_minor):
                        correctNotes += 1

        allRatios.append(correctNotes/totNotes)

    print("Final avg scale consistency percentage : " + str(sum(allRatios)/len(allRatios) * 100))

# %% [markdown]
# Calculate scale consistency of original dataset

# %%
testingSongs = glob('audio/*.mid')
getAvgScaleConsistency(testingSongs)

# %% [markdown]
# Calculate scale consistency of testing dataset

# %%
testingSongs = glob('testMidi/*.mid')
getAvgScaleConsistency(testingSongs)

# %%
# !unzip -j rand_music.zip -d rand_music
# Out:
# Archive:  rand_music.zip
#   inflating: rand_music/0001.mid
#   inflating: rand_music/0002.mid
#   inflating: rand_music/0003.mid
#   inflating: rand_music/0004.mid
#   inflating: rand_music/0005.mid
#   inflating: rand_music/0006.mid
#   inflating: rand_music/0007.mid
#   inflating: rand_music/0008.mid
#   inflating: rand_music/0009.mid
#   inflating: rand_music/0010.mid
#   inflating: rand_music/0011.mid
#   inflating: rand_music/0012.mid
#   inflating: rand_music/0013.mid
#   inflating: rand_music/0014.mid
#   inflating: rand_music/0015.mid
#   inflating: rand_music/0016.mid
#   inflating: rand_music/0017.mid
#   inflating: rand_music/0018.mid
#   inflating: rand_music/0019.mid
#   inflating: rand_music/0020.mid
#   inflating: rand_music/0021.mid
#   inflating: rand_music/0022.mid
#   inflating: rand_music/0023.mid
#   inflating: rand_music/0024.mid
#   inflating: rand_music/0025.mid
#   inflating: rand_music/0026.mid
#   inflating: rand_music/0027.mid
#   inflating: rand_music/0028.mid
#   inflating: rand_music/0029.mid
#   inflating: rand_music/0030.mid
#   inflating: rand_music/0031.mid
#   inflating: rand_music/0032.mid
#   inflating: rand_music/0033.mid
#   inflating: rand_music/0034.mid
#   inflating: rand_music/0035.mid
#   inflating: rand_music/0036.mid
#   inflating: rand_music/0037.mid
#   inflating: rand_music/0038.mid
#   inflating: rand_music/0039.mid
#   inflating: rand_music/0040.mid
#   inflating: rand_music/0041.mid
#   inflating: rand_music/0042.mid
#   inflating: rand_music/0043.mid
#   inflating: rand_music/0044.mid
#   inflating: rand_music/0045.mid
#   inflating: rand_music/0046.mid
#   inflating: rand_music/0047.mid
#   inflating: rand_music/0048.mid
#   inflating: rand_music/0049.mid
#   inflating: rand_music/0050.mid
#   inflating: rand_music/0051.mid
#   inflating: rand_music/0052.mid
#   inflating: rand_music/0053.mid
#   inflating: rand_music/0054.mid
#   inflating: rand_music/0055.mid
#   inflating: rand_music/0056.mid
#   inflating: rand_music/0057.mid
#   inflating: rand_music/0058.mid
#   inflating: rand_music/0059.mid
#   inflating: rand_music/0060.mid
#   inflating: rand_music/0061.mid
#   inflating: rand_music/0062.mid
#   inflating: rand_music/0063.mid
#   inflating: rand_music/0064.mid
#   inflating: rand_music/0065.mid
#   inflating: rand_music/0066.mid
#   inflating: rand_music/0067.mid
#   inflating: rand_music/0068.mid
#   inflating: rand_music/0069.mid
#   inflating: rand_music/0070.mid
#   inflating: rand_music/0071.mid
#   inflating: rand_music/0072.mid
#   inflating: rand_music/0073.mid
#   inflating: rand_music/0074.mid
#   inflating: rand_music/0075.mid
#   inflating: rand_music/0076.mid
#   inflating: rand_music/0077.mid
#   inflating: rand_music/0078.mid
#   inflating: rand_music/0079.mid
#   inflating: rand_music/0080.mid
#   inflating: rand_music/0081.mid
#   inflating: rand_music/0082.mid
#   inflating: rand_music/0083.mid
#   inflating: rand_music/0084.mid
#   inflating: rand_music/0085.mid
#   inflating: rand_music/0086.mid
#   inflating: rand_music/0087.mid
#   inflating: rand_music/0088.mid
#   inflating: rand_music/0089.mid
#   inflating: rand_music/0090.mid
#   inflating: rand_music/0091.mid
#   inflating: rand_music/0092.mid
#   inflating: rand_music/0093.mid
#   inflating: rand_music/0094.mid
#   inflating: rand_music/0095.mid
#   inflating: rand_music/0096.mid
#   inflating: rand_music/0097.mid
#   inflating: rand_music/0098.mid
#   inflating: rand_music/0099.mid
#   inflating: rand_music/0100.mid
#   inflating: rand_music/0101.mid
#   inflating: rand_music/0102.mid
#   inflating: rand_music/0103.mid
#   inflating: rand_music/0104.mid
#   inflating: rand_music/0105.mid
#   inflating: rand_music/0106.mid
#   inflating: rand_music/0107.mid
#   inflating: rand_music/0108.mid
#   inflating: rand_music/0109.mid
#   inflating: rand_music/0110.mid
#   inflating: rand_music/0111.mid
#   inflating: rand_music/0112.mid
#   inflating: rand_music/0113.mid
#   inflating: rand_music/0114.mid
#   inflating: rand_music/0115.mid
#   inflating: rand_music/0116.mid
#   inflating: rand_music/0117.mid
#   inflating: rand_music/0118.mid
#   inflating: rand_music/0119.mid
#   inflating: rand_music/0120.mid
#   inflating: rand_music/0121.mid
#   inflating: rand_music/0122.mid
#   inflating: rand_music/0123.mid
#   inflating: rand_music/0124.mid
#   inflating: rand_music/0125.mid
#   inflating: rand_music/0126.mid
#   inflating: rand_music/0127.mid
#   inflating: rand_music/0128.mid
#   inflating: rand_music/0129.mid
#   inflating: rand_music/0130.mid
#   inflating: rand_music/0131.mid
#   inflating: rand_music/0132.mid
#   inflating: rand_music/0133.mid
#   inflating: rand_music/0134.mid
#   inflating: rand_music/0135.mid
#   inflating: rand_music/0136.mid
#   inflating: rand_music/0137.mid
#   inflating: rand_music/0138.mid
#   inflating: rand_music/0139.mid
#   inflating: rand_music/0140.mid
#   inflating: rand_music/0141.mid
#   inflating: rand_music/0142.mid
#   inflating: rand_music/0143.mid
#   inflating: rand_music/0144.mid
#   inflating: rand_music/0145.mid
#   inflating: rand_music/0146.mid
#   inflating: rand_music/0147.mid
#   inflating: rand_music/0148.mid
#   inflating: rand_music/0149.mid
#   inflating: rand_music/0150.mid
#   inflating: rand_music/0151.mid
#   inflating: rand_music/0152.mid
#   inflating: rand_music/0153.mid
#   inflating: rand_music/0154.mid
#   inflating: rand_music/0155.mid
#   inflating: rand_music/0156.mid
#   inflating: rand_music/0157.mid
#   inflating: rand_music/0158.mid
#   inflating: rand_music/0159.mid
#   inflating: rand_music/0160.mid
#   inflating: rand_music/0161.mid
#   inflating: rand_music/0162.mid
#   inflating: rand_music/0163.mid
#   inflating: rand_music/0164.mid
#   inflating: rand_music/0165.mid
#   inflating: rand_music/0166.mid
#   inflating: rand_music/0167.mid
#   inflating: rand_music/0168.mid
#   inflating: rand_music/0169.mid
#   inflating: rand_music/0170.mid
#   inflating: rand_music/0171.mid
#   inflating: rand_music/0172.mid
#   inflating: rand_music/0173.mid
#   inflating: rand_music/0174.mid
#   inflating: rand_music/0175.mid
#   inflating: rand_music/0176.mid
#   inflating: rand_music/0177.mid
#   inflating: rand_music/0178.mid
#   inflating: rand_music/0179.mid
#   inflating: rand_music/0180.mid
#   inflating: rand_music/0181.mid
#   inflating: rand_music/0182.mid
#   inflating: rand_music/0183.mid
#   inflating: rand_music/0184.mid
#   inflating: rand_music/0185.mid
#   inflating: rand_music/0186.mid
#   inflating: rand_music/0187.mid
#   inflating: rand_music/0188.mid
#   inflating: rand_music/0189.mid
#   inflating: rand_music/0190.mid
#   inflating: rand_music/0191.mid
#   inflating: rand_music/0192.mid
#   inflating: rand_music/0193.mid
#   inflating: rand_music/0194.mid
#   inflating: rand_music/0195.mid
#   inflating: rand_music/0196.mid
#   inflating: rand_music/0197.mid
#   inflating: rand_music/0198.mid
#   inflating: rand_music/0199.mid
#   inflating: rand_music/0200.mid
#   inflating: rand_music/0201.mid
#   inflating: rand_music/0202.mid
#   inflating: rand_music/0203.mid
#   inflating: rand_music/0204.mid
#   inflating: rand_music/0205.mid
#   inflating: rand_music/0206.mid
#   inflating: rand_music/0207.mid
#   inflating: rand_music/0208.mid
#   inflating: rand_music/0209.mid
#   inflating: rand_music/0210.mid
#   inflating: rand_music/0211.mid
#   inflating: rand_music/0212.mid
#   inflating: rand_music/0213.mid
#   inflating: rand_music/0214.mid
#   inflating: rand_music/0215.mid
#   inflating: rand_music/0216.mid
#   inflating: rand_music/0217.mid
#   inflating: rand_music/0218.mid
#   inflating: rand_music/0219.mid
#   inflating: rand_music/0220.mid
#   inflating: rand_music/0221.mid
#   inflating: rand_music/0222.mid
#   inflating: rand_music/0223.mid
#   inflating: rand_music/0224.mid
#   inflating: rand_music/0225.mid
#   inflating: rand_music/0226.mid
#   inflating: rand_music/0227.mid
#   inflating: rand_music/0228.mid
#   inflating: rand_music/0229.mid
#   inflating: rand_music/0230.mid
#   inflating: rand_music/0231.mid
#   inflating: rand_music/0232.mid
#   inflating: rand_music/0233.mid
#   inflating: rand_music/0234.mid
#   inflating: rand_music/0235.mid
#   inflating: rand_music/0236.mid
#   inflating: rand_music/0237.mid
#   inflating: rand_music/0238.mid
#   inflating: rand_music/0239.mid
#   inflating: rand_music/0240.mid
#   inflating: rand_music/0241.mid
#   inflating: rand_music/0242.mid
#   inflating: rand_music/0243.mid
#   inflating: rand_music/0244.mid
#   inflating: rand_music/0245.mid
#   inflating: rand_music/0246.mid
#   inflating: rand_music/0247.mid
#   inflating: rand_music/0248.mid
#   inflating: rand_music/0249.mid
#   inflating: rand_music/0250.mid
#   inflating: rand_music/0251.mid
#   inflating: rand_music/0252.mid
#   inflating: rand_music/0253.mid
#   inflating: rand_music/0254.mid
#   inflating: rand_music/0255.mid
#   inflating: rand_music/0256.mid
#   inflating: rand_music/0257.mid
#   inflating: rand_music/0258.mid
#   inflating: rand_music/0259.mid
#   inflating: rand_music/0260.mid
#   inflating: rand_music/0261.mid
#   inflating: rand_music/0262.mid
#   inflating: rand_music/0263.mid
#   inflating: rand_music/0264.mid
#   inflating: rand_music/0265.mid
#   inflating: rand_music/0266.mid
#   inflating: rand_music/0267.mid
#   inflating: rand_music/0268.mid
#   inflating: rand_music/0269.mid
#   inflating: rand_music/0270.mid
#   inflating: rand_music/0271.mid
#   inflating: rand_music/0272.mid
#   inflating: rand_music/0273.mid
#   inflating: rand_music/0274.mid
#   inflating: rand_music/0275.mid
#   inflating: rand_music/0276.mid
#   inflating: rand_music/0277.mid
#   inflating: rand_music/0278.mid
#   inflating: rand_music/0279.mid
#   inflating: rand_music/0280.mid
#   inflating: rand_music/0281.mid
#   inflating: rand_music/0282.mid
#   inflating: rand_music/0283.mid
#   inflating: rand_music/0284.mid
#   inflating: rand_music/0285.mid
#   inflating: rand_music/0286.mid
#   inflating: rand_music/0287.mid
#   inflating: rand_music/0288.mid
#   inflating: rand_music/0289.mid
#   inflating: rand_music/0290.mid
#   inflating: rand_music/0291.mid
#   inflating: rand_music/0292.mid
#   inflating: rand_music/0293.mid
#   inflating: rand_music/0294.mid
#   inflating: rand_music/0295.mid
#   inflating: rand_music/0296.mid
#   inflating: rand_music/0297.mid
#   inflating: rand_music/0298.mid
#   inflating: rand_music/0299.mid
#   inflating: rand_music/0300.mid
#   inflating: rand_music/0301.mid
#   inflating: rand_music/0302.mid
#   inflating: rand_music/0303.mid
#   inflating: rand_music/0304.mid
#   inflating: rand_music/0305.mid
#   inflating: rand_music/0306.mid
#   inflating: rand_music/0307.mid
#   inflating: rand_music/0308.mid
#   inflating: rand_music/0309.mid
#   inflating: rand_music/0310.mid
#   inflating: rand_music/0311.mid
#   inflating: rand_music/0312.mid
#   inflating: rand_music/0313.mid
#   inflating: rand_music/0314.mid
#   inflating: rand_music/0315.mid
#   inflating: rand_music/0316.mid
#   inflating: rand_music/0317.mid
#   inflating: rand_music/0318.mid
#   inflating: rand_music/0319.mid
#   inflating: rand_music/0320.mid
#   inflating: rand_music/0321.mid
#   inflating: rand_music/0322.mid
#   inflating: rand_music/0323.mid
#   inflating: rand_music/0324.mid
#   inflating: rand_music/0325.mid
#   inflating: rand_music/0326.mid
#   inflating: rand_music/0327.mid
#   inflating: rand_music/0328.mid
#   inflating: rand_music/0329.mid
#   inflating: rand_music/0330.mid
#   inflating: rand_music/0331.mid
#   inflating: rand_music/0332.mid
#   inflating: rand_music/0333.mid
#   inflating: rand_music/0334.mid
#   inflating: rand_music/0335.mid
#   inflating: rand_music/0336.mid
#   inflating: rand_music/0337.mid
#   inflating: rand_music/0338.mid
#   inflating: rand_music/0339.mid
#   inflating: rand_music/0340.mid
#   inflating: rand_music/0341.mid
#   inflating: rand_music/0342.mid
#   inflating: rand_music/0343.mid
#   inflating: rand_music/0344.mid
#   inflating: rand_music/0345.mid
#   inflating: rand_music/0346.mid
#   inflating: rand_music/0347.mid
#   inflating: rand_music/0348.mid
#   inflating: rand_music/0349.mid
#   inflating: rand_music/0350.mid
#   inflating: rand_music/0351.mid
#   inflating: rand_music/0352.mid
#   inflating: rand_music/0353.mid
#   inflating: rand_music/0354.mid
#   inflating: rand_music/0355.mid
#   inflating: rand_music/0356.mid
#   inflating: rand_music/0357.mid
#   inflating: rand_music/0358.mid
#   inflating: rand_music/0359.mid
#   inflating: rand_music/0360.mid
#   inflating: rand_music/0361.mid
#   inflating: rand_music/0362.mid
#   inflating: rand_music/0363.mid
#   inflating: rand_music/0364.mid
#   inflating: rand_music/0365.mid
#   inflating: rand_music/0366.mid
#   inflating: rand_music/0367.mid
#   inflating: rand_music/0368.mid
#   inflating: rand_music/0369.mid
#   inflating: rand_music/0370.mid
#   inflating: rand_music/0371.mid
#   inflating: rand_music/0372.mid
#   inflating: rand_music/0373.mid
#   inflating: rand_music/0374.mid
#   inflating: rand_music/0375.mid
#   inflating: rand_music/0376.mid
#   inflating: rand_music/0377.mid
#   inflating: rand_music/0378.mid
#   inflating: rand_music/0379.mid
#   inflating: rand_music/0380.mid
#   inflating: rand_music/0381.mid
#   inflating: rand_music/0382.mid
#   inflating: rand_music/0383.mid
#   inflating: rand_music/0384.mid
#   inflating: rand_music/0385.mid
#   inflating: rand_music/0386.mid
#   inflating: rand_music/0387.mid
#   inflating: rand_music/0388.mid
#   inflating: rand_music/0389.mid
#   inflating: rand_music/0390.mid
#   inflating: rand_music/0391.mid
#   inflating: rand_music/0392.mid
#   inflating: rand_music/0393.mid
#   inflating: rand_music/0394.mid
#   inflating: rand_music/0395.mid
#   inflating: rand_music/0396.mid
#   inflating: rand_music/0397.mid
#   inflating: rand_music/0398.mid
#   inflating: rand_music/0399.mid
#   inflating: rand_music/0400.mid
#   inflating: rand_music/0401.mid
#   inflating: rand_music/0402.mid
#   inflating: rand_music/0403.mid
#   inflating: rand_music/0404.mid
#   inflating: rand_music/0405.mid
#   inflating: rand_music/0406.mid
#   inflating: rand_music/0407.mid
#   inflating: rand_music/0408.mid
#   inflating: rand_music/0409.mid
#   inflating: rand_music/0410.mid
#   inflating: rand_music/0411.mid
#   inflating: rand_music/0412.mid
#   inflating: rand_music/0413.mid
#   inflating: rand_music/0414.mid
#   inflating: rand_music/0415.mid
#   inflating: rand_music/0416.mid
#   inflating: rand_music/0417.mid
#   inflating: rand_music/0418.mid
#   inflating: rand_music/0419.mid
#   inflating: rand_music/0420.mid
#   inflating: rand_music/0421.mid
#   inflating: rand_music/0422.mid
#   inflating: rand_music/0423.mid
#   inflating: rand_music/0424.mid
#   inflating: rand_music/0425.mid
#   inflating: rand_music/0426.mid
#   inflating: rand_music/0427.mid
#   inflating: rand_music/0428.mid
#   inflating: rand_music/0429.mid
#   inflating: rand_music/0430.mid
#   inflating: rand_music/0431.mid
#   inflating: rand_music/0432.mid
#   inflating: rand_music/0433.mid
#   inflating: rand_music/0434.mid
#   inflating: rand_music/0435.mid
#   inflating: rand_music/0436.mid
#   inflating: rand_music/0437.mid
#   inflating: rand_music/0438.mid
#   inflating: rand_music/0439.mid
#   inflating: rand_music/0440.mid
#   inflating: rand_music/0441.mid
#   inflating: rand_music/0442.mid
#   inflating: rand_music/0443.mid
#   inflating: rand_music/0444.mid
#   inflating: rand_music/0445.mid
#   inflating: rand_music/0446.mid
#   inflating: rand_music/0447.mid
#   inflating: rand_music/0448.mid
#   inflating: rand_music/0449.mid
#   inflating: rand_music/0450.mid
#   inflating: rand_music/0451.mid
#   inflating: rand_music/0452.mid
#   inflating: rand_music/0453.mid
#   inflating: rand_music/0454.mid
#   inflating: rand_music/0455.mid
#   inflating: rand_music/0456.mid
#   inflating: rand_music/0457.mid
#   inflating: rand_music/0458.mid
#   inflating: rand_music/0459.mid
#   inflating: rand_music/0460.mid
#   inflating: rand_music/0461.mid
#   inflating: rand_music/0462.mid
#   inflating: rand_music/0463.mid
#   inflating: rand_music/0464.mid
#   inflating: rand_music/0465.mid
#   inflating: rand_music/0466.mid
#   inflating: rand_music/0467.mid
#   inflating: rand_music/0468.mid
#   inflating: rand_music/0469.mid
#   inflating: rand_music/0470.mid
#   inflating: rand_music/0471.mid
#   inflating: rand_music/0472.mid
#   inflating: rand_music/0473.mid
#   inflating: rand_music/0474.mid
#   inflating: rand_music/0475.mid
#   inflating: rand_music/0476.mid
#   inflating: rand_music/0477.mid
#   inflating: rand_music/0478.mid
#   inflating: rand_music/0479.mid
#   inflating: rand_music/0480.mid
#   inflating: rand_music/0481.mid
#   inflating: rand_music/0482.mid
#   inflating: rand_music/0483.mid
#   inflating: rand_music/0484.mid
#   inflating: rand_music/0485.mid
#   inflating: rand_music/0486.mid
#   inflating: rand_music/0487.mid
#   inflating: rand_music/0488.mid
#   inflating: rand_music/0489.mid
#   inflating: rand_music/0490.mid
#   inflating: rand_music/0491.mid
#   inflating: rand_music/0492.mid
#   inflating: rand_music/0493.mid
#   inflating: rand_music/0494.mid
#   inflating: rand_music/0495.mid
#   inflating: rand_music/0496.mid
#   inflating: rand_music/0497.mid
#   inflating: rand_music/0498.mid
#   inflating: rand_music/0499.mid
#   inflating: rand_music/0500.mid
#   inflating: rand_music/0501.mid
#   inflating: rand_music/0502.mid
#   inflating: rand_music/0503.mid
#   inflating: rand_music/0504.mid
#   inflating: rand_music/0505.mid
#   inflating: rand_music/0506.mid
#   inflating: rand_music/0507.mid
#   inflating: rand_music/0508.mid
#   inflating: rand_music/0509.mid
#   inflating: rand_music/0510.mid
#   inflating: rand_music/0511.mid
#   inflating: rand_music/0512.mid
#   inflating: rand_music/0513.mid
#   inflating: rand_music/0514.mid
#   inflating: rand_music/0515.mid
#   inflating: rand_music/0516.mid
#   inflating: rand_music/0517.mid
#   inflating: rand_music/0518.mid
#   inflating: rand_music/0519.mid
#   inflating: rand_music/0520.mid
#   inflating: rand_music/0521.mid
#   inflating: rand_music/0522.mid
#   inflating: rand_music/0523.mid
#   inflating: rand_music/0524.mid
#   inflating: rand_music/0525.mid
#   inflating: rand_music/0526.mid
#   inflating: rand_music/0527.mid
#   inflating: rand_music/0528.mid
#   inflating: rand_music/0529.mid
#   inflating: rand_music/0530.mid
#   inflating: rand_music/0531.mid
#   inflating: rand_music/0532.mid
#   inflating: rand_music/0533.mid
#   inflating: rand_music/0534.mid
#   inflating: rand_music/0535.mid
#   inflating: rand_music/0536.mid
#   inflating: rand_music/0537.mid
#   inflating: rand_music/0538.mid
#   inflating: rand_music/0539.mid
#   inflating: rand_music/0540.mid
#   inflating: rand_music/0541.mid
#   inflating: rand_music/0542.mid
#   inflating: rand_music/0543.mid
#   inflating: rand_music/0544.mid
#   inflating: rand_music/0545.mid
#   inflating: rand_music/0546.mid
#   inflating: rand_music/0547.mid
#   inflating: rand_music/0548.mid
#   inflating: rand_music/0549.mid
#   inflating: rand_music/0550.mid
#   inflating: rand_music/0551.mid
#   inflating: rand_music/0552.mid
#   inflating: rand_music/0553.mid
#   inflating: rand_music/0554.mid
#   inflating: rand_music/0555.mid
#   inflating: rand_music/0556.mid
#   inflating: rand_music/0557.mid
#   inflating: rand_music/0558.mid
#   inflating: rand_music/0559.mid
#   inflating: rand_music/0560.mid
#   inflating: rand_music/0561.mid
#   inflating: rand_music/0562.mid
#   inflating: rand_music/0563.mid
#   inflating: rand_music/0564.mid
#   inflating: rand_music/0565.mid
#   inflating: rand_music/0566.mid
#   inflating: rand_music/0567.mid
#   inflating: rand_music/0568.mid
#   inflating: rand_music/0569.mid
#   inflating: rand_music/0570.mid
#   inflating: rand_music/0571.mid
#   inflating: rand_music/0572.mid
#   inflating: rand_music/0573.mid
#   inflating: rand_music/0574.mid
#   inflating: rand_music/0575.mid
#   inflating: rand_music/0576.mid
#   inflating: rand_music/0577.mid
#   inflating: rand_music/0578.mid
#   inflating: rand_music/0579.mid
#   inflating: rand_music/0580.mid
#   inflating: rand_music/0581.mid
#   inflating: rand_music/0582.mid
#   inflating: rand_music/0583.mid
#   inflating: rand_music/0584.mid
#   inflating: rand_music/0585.mid
#   inflating: rand_music/0586.mid
#   inflating: rand_music/0587.mid
#   inflating: rand_music/0588.mid
#   inflating: rand_music/0589.mid
#   inflating: rand_music/0590.mid
#   inflating: rand_music/0591.mid
#   inflating: rand_music/0592.mid
#   inflating: rand_music/0593.mid
#   inflating: rand_music/0594.mid
#   inflating: rand_music/0595.mid
#   inflating: rand_music/0596.mid
#   inflating: rand_music/0597.mid
#   inflating: rand_music/0598.mid
#   inflating: rand_music/0599.mid
#   inflating: rand_music/0600.mid
#   inflating: rand_music/0601.mid
#   inflating: rand_music/0602.mid
#   inflating: rand_music/0603.mid
#   inflating: rand_music/0604.mid
#   inflating: rand_music/0605.mid
#   inflating: rand_music/0606.mid
#   inflating: rand_music/0607.mid
#   inflating: rand_music/0608.mid
#   inflating: rand_music/0609.mid
#   inflating: rand_music/0610.mid
#   inflating: rand_music/0611.mid
#   inflating: rand_music/0612.mid
#   inflating: rand_music/0613.mid
#   inflating: rand_music/0614.mid
#   inflating: rand_music/0615.mid
#   inflating: rand_music/0616.mid
#   inflating: rand_music/0617.mid
#   inflating: rand_music/0618.mid
#   inflating: rand_music/0619.mid
#   inflating: rand_music/0620.mid
#   inflating: rand_music/0621.mid
#   inflating: rand_music/0622.mid
#   inflating: rand_music/0623.mid
#   inflating: rand_music/0624.mid
#   inflating: rand_music/0625.mid
#   inflating: rand_music/0626.mid
#   inflating: rand_music/0627.mid
#   inflating: rand_music/0628.mid
#   inflating: rand_music/0629.mid
#   inflating: rand_music/0630.mid
#   inflating: rand_music/0631.mid
#   inflating: rand_music/0632.mid
#   inflating: rand_music/0633.mid
#   inflating: rand_music/0634.mid
#   inflating: rand_music/0635.mid
#   inflating: rand_music/0636.mid
#   inflating: rand_music/0637.mid
#   inflating: rand_music/0638.mid
#   inflating: rand_music/0639.mid
#   inflating: rand_music/0640.mid
#   inflating: rand_music/0641.mid
#   inflating: rand_music/0642.mid
#   inflating: rand_music/0643.mid
#   inflating: rand_music/0644.mid
#   inflating: rand_music/0645.mid
#   inflating: rand_music/0646.mid
#   inflating: rand_music/0647.mid
#   inflating: rand_music/0648.mid
#   inflating: rand_music/0649.mid
#   inflating: rand_music/0650.mid
#   inflating: rand_music/0651.mid
#   inflating: rand_music/0652.mid
#   inflating: rand_music/0653.mid
#   inflating: rand_music/0654.mid
#   inflating: rand_music/0655.mid
#   inflating: rand_music/0656.mid
#   inflating: rand_music/0657.mid
#   inflating: rand_music/0658.mid
#   inflating: rand_music/0659.mid
#   inflating: rand_music/0660.mid
#   inflating: rand_music/0661.mid
#   inflating: rand_music/0662.mid
#   inflating: rand_music/0663.mid
#   inflating: rand_music/0664.mid
#   inflating: rand_music/0665.mid
#   inflating: rand_music/0666.mid
#   inflating: rand_music/0667.mid
#   inflating: rand_music/0668.mid
#   inflating: rand_music/0669.mid
#   inflating: rand_music/0670.mid
#   inflating: rand_music/0671.mid
#   inflating: rand_music/0672.mid
#   inflating: rand_music/0673.mid
#   inflating: rand_music/0674.mid
#   inflating: rand_music/0675.mid
#   inflating: rand_music/0676.mid
#   inflating: rand_music/0677.mid
#   inflating: rand_music/0678.mid
#   inflating: rand_music/0679.mid
#   inflating: rand_music/0680.mid
#   inflating: rand_music/0681.mid
#   inflating: rand_music/0682.mid
#   inflating: rand_music/0683.mid
#   inflating: rand_music/0684.mid
#   inflating: rand_music/0685.mid
#   inflating: rand_music/0686.mid
#   inflating: rand_music/0687.mid
#   inflating: rand_music/0688.mid
#   inflating: rand_music/0689.mid
#   inflating: rand_music/0690.mid
#   inflating: rand_music/0691.mid
#   inflating: rand_music/0692.mid
#   inflating: rand_music/0693.mid
#   inflating: rand_music/0694.mid
#   inflating: rand_music/0695.mid
#   inflating: rand_music/0696.mid
#   inflating: rand_music/0697.mid
#   inflating: rand_music/0698.mid
#   inflating: rand_music/0699.mid
#   inflating: rand_music/0700.mid
#   inflating: rand_music/0701.mid
#   inflating: rand_music/0702.mid
#   inflating: rand_music/0703.mid
#   inflating: rand_music/0704.mid
#   inflating: rand_music/0705.mid
#   inflating: rand_music/0706.mid
#   inflating: rand_music/0707.mid
#   inflating: rand_music/0708.mid
#   inflating: rand_music/0709.mid
#   inflating: rand_music/0710.mid
#   inflating: rand_music/0711.mid
#   inflating: rand_music/0712.mid
#   inflating: rand_music/0713.mid
#   inflating: rand_music/0714.mid
#   inflating: rand_music/0715.mid
#   inflating: rand_music/0716.mid
#   inflating: rand_music/0717.mid
#   inflating: rand_music/0718.mid
#   inflating: rand_music/0719.mid
#   inflating: rand_music/0720.mid
#   inflating: rand_music/0721.mid
#   inflating: rand_music/0722.mid
#   inflating: rand_music/0723.mid
#   inflating: rand_music/0724.mid
#   inflating: rand_music/0725.mid
#   inflating: rand_music/0726.mid
#   inflating: rand_music/0727.mid
#   inflating: rand_music/0728.mid
#   inflating: rand_music/0729.mid
#   inflating: rand_music/0730.mid
#   inflating: rand_music/0731.mid
#   inflating: rand_music/0732.mid
#   inflating: rand_music/0733.mid
#   inflating: rand_music/0734.mid
#   inflating: rand_music/0735.mid
#   inflating: rand_music/0736.mid
#   inflating: rand_music/0737.mid
#   inflating: rand_music/0738.mid
#   inflating: rand_music/0739.mid
#   inflating: rand_music/0740.mid
#   inflating: rand_music/0741.mid
#   inflating: rand_music/0742.mid
#   inflating: rand_music/0743.mid
#   inflating: rand_music/0744.mid
#   inflating: rand_music/0745.mid
#   inflating: rand_music/0746.mid
#   inflating: rand_music/0747.mid
#   inflating: rand_music/0748.mid
#   inflating: rand_music/0749.mid
#   inflating: rand_music/0750.mid
#   inflating: rand_music/0751.mid
#   inflating: rand_music/0752.mid
#   inflating: rand_music/0753.mid
#   inflating: rand_music/0754.mid
#   inflating: rand_music/0755.mid
#   inflating: rand_music/0756.mid
#   inflating: rand_music/0757.mid
#   inflating: rand_music/0758.mid
#   inflating: rand_music/0759.mid
#   inflating: rand_music/0760.mid
#   inflating: rand_music/0761.mid
#   inflating: rand_music/0762.mid
#   inflating: rand_music/0763.mid
#   inflating: rand_music/0764.mid
#   inflating: rand_music/0765.mid
#   inflating: rand_music/0766.mid
#   inflating: rand_music/0767.mid
#   inflating: rand_music/0768.mid
#   inflating: rand_music/0769.mid
#   inflating: rand_music/0770.mid
#   inflating: rand_music/0771.mid
#   inflating: rand_music/0772.mid
#   inflating: rand_music/0773.mid
#   inflating: rand_music/0774.mid
#   inflating: rand_music/0775.mid
#   inflating: rand_music/0776.mid
#   inflating: rand_music/0777.mid
#   inflating: rand_music/0778.mid
#   inflating: rand_music/0779.mid
#   inflating: rand_music/0780.mid
#   inflating: rand_music/0781.mid
#   inflating: rand_music/0782.mid
#   inflating: rand_music/0783.mid
#   inflating: rand_music/0784.mid
#   inflating: rand_music/0785.mid
#   inflating: rand_music/0786.mid
#   inflating: rand_music/0787.mid
#   inflating: rand_music/0788.mid
#   inflating: rand_music/0789.mid
#   inflating: rand_music/0790.mid
#   inflating: rand_music/0791.mid
#   inflating: rand_music/0792.mid
#   inflating: rand_music/0793.mid
#   inflating: rand_music/0794.mid
#   inflating: rand_music/0795.mid
#   inflating: rand_music/0796.mid
#   inflating: rand_music/0797.mid
#   inflating: rand_music/0798.mid
#   inflating: rand_music/0799.mid
#   inflating: rand_music/0800.mid
#   inflating: rand_music/0801.mid
#   inflating: rand_music/0802.mid
#   inflating: rand_music/0803.mid
#   inflating: rand_music/0804.mid
#   inflating: rand_music/0805.mid
#   inflating: rand_music/0806.mid
#   inflating: rand_music/0807.mid
#   inflating: rand_music/0808.mid
#   inflating: rand_music/0809.mid
#   inflating: rand_music/0810.mid
#   inflating: rand_music/0811.mid
#   inflating: rand_music/0812.mid
#   inflating: rand_music/0813.mid
#   inflating: rand_music/0814.mid
#   inflating: rand_music/0815.mid
#   inflating: rand_music/0816.mid
#   inflating: rand_music/0817.mid
#   inflating: rand_music/0818.mid
#   inflating: rand_music/0819.mid
#   inflating: rand_music/0820.mid
#   inflating: rand_music/0821.mid
#   inflating: rand_music/0822.mid
#   inflating: rand_music/0823.mid
#   inflating: rand_music/0824.mid
#   inflating: rand_music/0825.mid
#   inflating: rand_music/0826.mid
#   inflating: rand_music/0827.mid
#   inflating: rand_music/0828.mid
#   inflating: rand_music/0829.mid
#   inflating: rand_music/0830.mid
#   inflating: rand_music/0831.mid
#   inflating: rand_music/0832.mid
#   inflating: rand_music/0833.mid
#   inflating: rand_music/0834.mid
#   inflating: rand_music/0835.mid
#   inflating: rand_music/0836.mid
#   inflating: rand_music/0837.mid
#   inflating: rand_music/0838.mid
#   inflating: rand_music/0839.mid
#   inflating: rand_music/0840.mid
#   inflating: rand_music/0841.mid
#   inflating: rand_music/0842.mid
#   inflating: rand_music/0843.mid
#   inflating: rand_music/0844.mid
#   inflating: rand_music/0845.mid
#   inflating: rand_music/0846.mid
#   inflating: rand_music/0847.mid
#   inflating: rand_music/0848.mid
#   inflating: rand_music/0849.mid
#   inflating: rand_music/0850.mid
#   inflating: rand_music/0851.mid
#   inflating: rand_music/0852.mid
#   inflating: rand_music/0853.mid
#   inflating: rand_music/0854.mid
#   inflating: rand_music/0855.mid
#   inflating: rand_music/0856.mid
#   inflating: rand_music/0857.mid
#   inflating: rand_music/0858.mid
#   inflating: rand_music/0859.mid
#   inflating: rand_music/0860.mid
#   inflating: rand_music/0861.mid
#   inflating: rand_music/0862.mid
#   inflating: rand_music/0863.mid
#   inflating: rand_music/0864.mid
#   inflating: rand_music/0865.mid
#   inflating: rand_music/0866.mid
#   inflating: rand_music/0867.mid
#   inflating: rand_music/0868.mid
#   inflating: rand_music/0869.mid
#   inflating: rand_music/0870.mid
#   inflating: rand_music/0871.mid
#   inflating: rand_music/0872.mid
#   inflating: rand_music/0873.mid
#   inflating: rand_music/0874.mid
#   inflating: rand_music/0875.mid
#   inflating: rand_music/0876.mid
#   inflating: rand_music/0877.mid
#   inflating: rand_music/0878.mid
#   inflating: rand_music/0879.mid
#   inflating: rand_music/0880.mid
#   inflating: rand_music/0881.mid
#   inflating: rand_music/0882.mid
#   inflating: rand_music/0883.mid
#   inflating: rand_music/0884.mid
#   inflating: rand_music/0885.mid
#   inflating: rand_music/0886.mid
#   inflating: rand_music/0887.mid
#   inflating: rand_music/0888.mid
#   inflating: rand_music/0889.mid
#   inflating: rand_music/0890.mid
#   inflating: rand_music/0891.mid
#   inflating: rand_music/0892.mid
#   inflating: rand_music/0893.mid
#   inflating: rand_music/0894.mid
#   inflating: rand_music/0895.mid
#   inflating: rand_music/0896.mid
#   inflating: rand_music/0897.mid
#   inflating: rand_music/0898.mid
#   inflating: rand_music/0899.mid
#   inflating: rand_music/0900.mid
#   inflating: rand_music/0901.mid
#   inflating: rand_music/0902.mid
#   inflating: rand_music/0903.mid
#   inflating: rand_music/0904.mid
#   inflating: rand_music/0905.mid
#   inflating: rand_music/0906.mid
#   inflating: rand_music/0907.mid
#   inflating: rand_music/0908.mid
#   inflating: rand_music/0909.mid
#   inflating: rand_music/0910.mid
#   inflating: rand_music/0911.mid
#   inflating: rand_music/0912.mid
#   inflating: rand_music/0913.mid
#   inflating: rand_music/0914.mid
#   inflating: rand_music/0915.mid
#   inflating: rand_music/0916.mid
#   inflating: rand_music/0917.mid
#   inflating: rand_music/0918.mid
#   inflating: rand_music/0919.mid
#   inflating: rand_music/0920.mid
#   inflating: rand_music/0921.mid
#   inflating: rand_music/0922.mid
#   inflating: rand_music/0923.mid
#   inflating: rand_music/0924.mid
#   inflating: rand_music/0925.mid
#   inflating: rand_music/0926.mid
#   inflating: rand_music/0927.mid
#   inflating: rand_music/0928.mid
#   inflating: rand_music/0929.mid
#   inflating: rand_music/0930.mid
#   inflating: rand_music/0931.mid
#   inflating: rand_music/0932.mid
#   inflating: rand_music/0933.mid
#   inflating: rand_music/0934.mid
#   inflating: rand_music/0935.mid
#   inflating: rand_music/0936.mid
#   inflating: rand_music/0937.mid
#   inflating: rand_music/0938.mid
#   inflating: rand_music/0939.mid
#   inflating: rand_music/0940.mid
#   inflating: rand_music/0941.mid
#   inflating: rand_music/0942.mid
#   inflating: rand_music/0943.mid
#   inflating: rand_music/0944.mid
#   inflating: rand_music/0945.mid
#   inflating: rand_music/0946.mid
#   inflating: rand_music/0947.mid
#   inflating: rand_music/0948.mid
#   inflating: rand_music/0949.mid
#   inflating: rand_music/0950.mid
#   inflating: rand_music/0951.mid
#   inflating: rand_music/0952.mid
#   inflating: rand_music/0953.mid
#   inflating: rand_music/0954.mid
#   inflating: rand_music/0955.mid
#   inflating: rand_music/0956.mid
#   inflating: rand_music/0957.mid
#   inflating: rand_music/0958.mid
#   inflating: rand_music/0959.mid
#   inflating: rand_music/0960.mid
#   inflating: rand_music/0961.mid
#   inflating: rand_music/0962.mid
#   inflating: rand_music/0963.mid
#   inflating: rand_music/0964.mid
#   inflating: rand_music/0965.mid
#   inflating: rand_music/0966.mid
#   inflating: rand_music/0967.mid
#   inflating: rand_music/0968.mid
#   inflating: rand_music/0969.mid
#   inflating: rand_music/0970.mid
#   inflating: rand_music/0971.mid
#   inflating: rand_music/0972.mid
#   inflating: rand_music/0973.mid
#   inflating: rand_music/0974.mid
#   inflating: rand_music/0975.mid
#   inflating: rand_music/0976.mid
#   inflating: rand_music/0977.mid
#   inflating: rand_music/0978.mid
#   inflating: rand_music/0979.mid
#   inflating: rand_music/0980.mid
#   inflating: rand_music/0981.mid
#   inflating: rand_music/0982.mid
#   inflating: rand_music/0983.mid
#   inflating: rand_music/0984.mid
#   inflating: rand_music/0985.mid
#   inflating: rand_music/0986.mid
#   inflating: rand_music/0987.mid
#   inflating: rand_music/0988.mid
#   inflating: rand_music/0989.mid
#   inflating: rand_music/0990.mid
#   inflating: rand_music/0991.mid
#   inflating: rand_music/0992.mid
#   inflating: rand_music/0993.mid
#   inflating: rand_music/0994.mid
#   inflating: rand_music/0995.mid
#   inflating: rand_music/0996.mid
#   inflating: rand_music/0997.mid
#   inflating: rand_music/0998.mid
#   inflating: rand_music/0999.mid
#   inflating: rand_music/1000.mid
