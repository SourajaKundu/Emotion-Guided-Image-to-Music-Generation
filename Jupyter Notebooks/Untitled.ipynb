# %%
import matplotlib.pyplot as plt

# Example lists of loss values over 15 epochs for two models
LSTM = [10, 6.94345, 6.65932, 6.46854, 6.33793, 6.23134, 6.14835, 6.08619, 6.03603, 5.99751, 5.96270, 5.93413, 5.90689, 5.88200, 5.85550, 5.83130]
final = [10, 5.81881, 4.94465, 4.47973, 4.13094, 3.85639, 3.63305, 3.44999, 3.29722, 3.17200, 3.06265, 2.97234, 2.88731, 2.81492, 2.75162, 2.68831]

# Number of epochs
epochs = range(1, 17)

# Plotting the loss vs. epoch for both models
plt.figure(figsize=(10, 6))
plt.plot(epochs, LSTM, label='LSTM baseline model', marker='o')
plt.plot(epochs, final, label='Proposed Trans_enc3_Dec3_VA_loss model', marker='o')

# Adding title and labels
plt.title('Loss vs. Epoch Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Displaying the plot
plt.grid(True)
plt.show()

# %%
}
